# %% [markdown]
# # Imports and Colab Mount

# %%
import datetime
import seaborn as sn
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats as stats
import glob
from math import sqrt

from sklearn.preprocessing import StandardScaler, MinMaxScaler

import keras
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, LSTM, LeakyReLU, Dropout, GRU, SimpleRNN, Input, LSTM, Dense, Bidirectional, Concatenate, Reshape, Lambda, Bidirectional
from keras.models import Model, Sequential
from keras import backend as K
from tensorflow.keras import layers
from keras.callbacks import Callback, ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
import seaborn as sns

from numpy.random import seed
#from tensorflow import set_random_seed

# %matplotlib inline

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load Data

# %%
hourly = pd.read_excel("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/BASEFORTALEZAhorario.xlsx", index_col=0, parse_dates=[["Data", "HORA (UTC)"]])
hourly = hourly[ ['Velocidade'] + [ col for col in hourly.columns if col != 'Velocidade' ] ]
quarto = int(hourly["Velocidade"].shape[0]/4)

#resid_train = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/natalhora_resid_train.csv").drop("Unnamed: 0", axis=1)
#resid_test = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/natalhora_resid_test2.csv").drop("Unnamed: 0", axis=1)

sarima_pred = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/fortalezahora_prediction_bad.csv").drop("Unnamed: 0", axis=1)
sarima_pred2 = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/fortalezahora_prediction_good.csv").drop("Unnamed: 0", axis=1)

#hourly["Velocidade"] = pd.concat([resid_train, resid_test]).reset_index()["0"].values
resid_series = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/fortalezahora_resid_series.csv").drop("Unnamed: 0", axis=1)

train_h = hourly.iloc[:quarto*2]
valid_h = hourly.iloc[quarto*2:quarto*3]
test_h = hourly.iloc[quarto*3:]

# %%
train_h['Velocidade'].to_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/fortalezavelocidade_train.csv")
resid_series['0'][:372].to_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/fortalezaresid_train.csv")

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
def make_data(data, timestep, resid_check=False):
  values = data.values
  values = values.astype('float32')
  #scaler = MinMaxScaler(feature_range=(0, 1))
  #scaled = scaler.fit_transform(values)
  
  timestep = timestep
  n_features = data.shape[1]
  n_obs = timestep * n_features
  reframed = series_to_supervised(values, timestep, 1)
  reframed = reframed.iloc[: , :1-n_features]

  values = reframed.values
  indice1 = train_h.shape[0]
  indice2 = valid_h.shape[0]

  train = values[:indice1, :]
  valid = values[indice1:indice1+indice2, :]
  test = values[indice1+indice2:, :]

  train_X, train_y = train[:, :-1], train[:, -1]
  valid_X, valid_y = valid[:, :-1], valid[:, -1]
  test_X, test_y = test[:, :-1], test[:, -1]

  if (resid_check==True):
    train_y = resid_train.values[:quarto*2]
    valid_y = resid_train.values[quarto*2:]

  scaler = MinMaxScaler(feature_range=(0, 1)).fit(train_X)
  train_X = scaler.transform(train_X)
  valid_X = scaler.transform(valid_X)
  test_X = scaler.transform(test_X)

  scaler_y = MinMaxScaler(feature_range=(0, 1)).fit(train_y.reshape(-1,1))
  train_y = scaler_y.transform(train_y.reshape(-1,1))
  valid_y = scaler_y.transform(valid_y.reshape(-1,1))
  test_y = scaler_y.transform(test_y.reshape(-1,1))

  train_X = train_X.reshape((train_X.shape[0], timestep, n_features))
  valid_X = valid_X.reshape((valid_X.shape[0], timestep, n_features))
  test_X = test_X.reshape((test_X.shape[0], timestep, n_features))
  return train_X, train_y, valid_X, valid_y, test_X, test_y

# %%
def make_data2(data, timestep, resid_check=False):
  values = data.values
  values = values.astype('float32')
  #scaler = MinMaxScaler(feature_range=(0, 1))
  #scaled = scaler.fit_transform(values)
  
  timestep = timestep
  n_features = data.shape[1]
  n_obs = timestep * n_features
  reframed = series_to_supervised(values, timestep, 1)
  reframed = reframed.iloc[: , :1-n_features]

  values = reframed.values
  indice1 = train_h.shape[0]
  indice2 = valid_h.shape[0]

  train = values[:indice1, :]
  valid = values[indice1:indice1+indice2, :]
  test = values[indice1+indice2:, :]

  train_X, train_y = train[:, :-1], train[:, -1]
  valid_X, valid_y = valid[:, :-1], valid[:, -1]
  test_X, test_y = test[:, :-1], test[:, -1]

  if (resid_check==True):
    train_y = resid_train.values[:quarto*2]
    valid_y = resid_train.values[quarto*2:]

  scaler = MinMaxScaler(feature_range=(0, 1)).fit(train_X)
  train_X = scaler.transform(train_X)
  valid_X = scaler.transform(valid_X)
  test_X = scaler.transform(test_X)

  scaler_y = MinMaxScaler(feature_range=(0, 1)).fit(train_y.reshape(-1,1))
  train_y = scaler_y.transform(train_y.reshape(-1,1))
  valid_y = scaler_y.transform(valid_y.reshape(-1,1))
  test_y = scaler_y.transform(test_y.reshape(-1,1))

  train_X = train_X.reshape((train_X.shape[0], timestep, n_features))
  valid_X = valid_X.reshape((valid_X.shape[0], timestep, n_features))
  test_X = test_X.reshape((test_X.shape[0], timestep, n_features))
  return train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y

# %%
def make_data3(df, timestep, resid_check=False, resid=False, univariate=False):

  data = df.copy()

  if resid==True:
    data['Velocidade'] = resid_series.values

  if univariate==True:
    values = data["Velocidade"].values
    values = values.astype('float32')
    values = values.reshape(-1, 1)

    timestep = timestep
    n_features = 1
    n_obs = timestep * n_features
    reframed = series_to_supervised(values, timestep, 1)

  else:
    values = data.values
    values = values.astype('float32')
    #scaler = MinMaxScaler(feature_range=(0, 1))
    #scaled = scaler.fit_transform(values)
    
    timestep = timestep
    n_features = data.shape[1]
    n_obs = timestep * n_features
    reframed = series_to_supervised(values, timestep, 1)
    reframed = reframed.iloc[: , :1-n_features]

  values = reframed.values
  indice1 = train_h.shape[0]
  indice2 = valid_h.shape[0]

  train = values[:indice1, :]
  valid = values[indice1:indice1+indice2, :]
  test = values[indice1+indice2:, :]

  train_X, train_y = train[:, :-1], train[:, -1]
  valid_X, valid_y = valid[:, :-1], valid[:, -1]
  test_X, test_y = test[:, :-1], test[:, -1]

  if (resid_check==True):
    train_y = resid_series.values[timestep:(quarto*2)+timestep]
    valid_y = resid_series.values[(quarto*2)+timestep:(quarto*3)+timestep]
    #test_y = resid_series.values[(quarto*3)+timestep:]
  if (resid==True):
    test_y = df['Velocidade'].values[(quarto*3)+timestep:]

  scaler = MinMaxScaler(feature_range=(0, 1)).fit(train_X)
  train_X = scaler.transform(train_X)
  valid_X = scaler.transform(valid_X)
  test_X = scaler.transform(test_X)

  scaler_y = MinMaxScaler(feature_range=(0, 1)).fit(train_y.reshape(-1,1))
  train_y = scaler_y.transform(train_y.reshape(-1,1))
  valid_y = scaler_y.transform(valid_y.reshape(-1,1))
  test_y = scaler_y.transform(test_y.reshape(-1,1))

  train_X = train_X.reshape((train_X.shape[0], timestep, n_features))
  valid_X = valid_X.reshape((valid_X.shape[0], timestep, n_features))
  test_X = test_X.reshape((test_X.shape[0], timestep, n_features))
  return train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y

# %% [markdown]
# # WanDB

# %%
# !pip install wandb -qq
import wandb
from wandb.keras import WandbCallback
# !wandb login
# Out:
#      |████████████████████████████████| 1.8 MB 5.6 MB/s
#      |████████████████████████████████| 145 kB 52.9 MB/s
#      |████████████████████████████████| 181 kB 57.4 MB/s
#      |████████████████████████████████| 63 kB 1.4 MB/s
#   Building wheel for pathtools (setup.py) ... done
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# # Train

# %% [markdown]
# # RNN

# %%
# Configure the sweep – specify the parameters to search through, the search strategy, the optimization metric et all.
sweep_config = {
    'name': 'RNN',
    'method': 'bayes', #grid, random
    'metric': {
      'name': 'best_val_loss',
      'goal': 'minimize'   
    },
    'parameters': {
        'batch_size': {
            'values': [256, 128, 64, 32]
        },
        'dropout': {
            'values': [0, 0.1, 0.3]
        },
        'units': {
            'values': [32, 64, 128, 256]
        },
        'timestep': {
            'distribution': "int_uniform",
            'min': 1,
            'max': 12
        },
        'lr': {
            'values': [1e-2, 1e-1]
        },
        'layers': {
            'values': [1, 2, 4, 8]
        },
        
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, entity="ancy", project="FORTALEZA-2022-06-22-HYBRID")
# Out:
# Create sweep with ID: kgxsxnr8
# Sweep URL: https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8

# %%
def create_rnn():
    config_defaults = {
    'batch_size': 128,
    'lr': 1e-3,
    'units': 64,
    'timestep': 3,
    'dropout': 0.3,
    'layers': 1,
    }

    wandb.init(config=config_defaults)
    config = wandb.config

    batch_size = config.batch_size
    lr         = config.lr
    num_units  = config.units
    timestep   = config.timestep
    dropout    = config.dropout
    layers     = config.layers

    train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y = make_data3(hourly, config.timestep, resid_check=True, resid=False, univariate=False)
    model = Sequential()

    if layers > 1:
      model.add(SimpleRNN(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout, return_sequences=True))

      for i in range(layers-2):
        model.add(SimpleRNN(units = num_units, dropout=dropout, return_sequences=True))

      model.add(SimpleRNN(units = num_units, dropout=dropout))

    else:
      model.add(SimpleRNN(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout))

    model.add(Dense(units = 1))

    model.compile(
        loss="mse",
        optimizer=Adam(learning_rate=lr)
    )

    model.fit(train_X, train_y, batch_size=batch_size,
              epochs=200, verbose=0, shuffle=False,
              validation_data=(valid_X, valid_y),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=10, restore_best_weights=True)])
    
    yhat = model.predict(test_X)
    yhat_inv = scaler_y.inverse_transform(yhat)
    resid_sum = (yhat_inv+sarima_pred.values[config.timestep:])
    resid_sum2 = (yhat_inv+sarima_pred2.values[config.timestep:])

    wandb.log({"Test_MSE": mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    wandb.log({"Test_RMSE": sqrt(mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y)))})

    wandb.log({"Test_MAE": mean_absolute_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    wandb.log({"Test_MAPE": mean_absolute_percentage_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    return model

# %%
wandb.agent(sweep_id, create_rnn, count=100)
# Out:
# wandb: Agent Starting Run: pvw30kev with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 7
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_092725-pvw30kev</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pvw30kev" target="_blank">fast-sweep-1</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.615 MB of 0.615 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▄▄▅▅▆▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▃▄▅▆▆▆▆▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.56163</td></tr><tr><td>Test_MAPE</td><td>0.16125</td></tr><tr><td>Test_MSE</td><td>0.48156</td></tr><tr><td>Test_RMSE</td><td>0.69395</td></tr><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.00955</td></tr><tr><td>epoch</td><td>11</td></tr><tr><td>loss</td><td>0.02792</td></tr><tr><td>val_loss</td><td>0.02218</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fast-sweep-1</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pvw30kev" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pvw30kev</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_092725-pvw30kev/logs</code>
# wandb: Agent Starting Run: meztpwq4 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.1
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	timestep: 6
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_092751-meztpwq4</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/meztpwq4" target="_blank">clear-sweep-2</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.225 MB of 0.225 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▆▃▃█▆▁▆▄▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.55868</td></tr><tr><td>Test_MAPE</td><td>0.16906</td></tr><tr><td>Test_MSE</td><td>0.49079</td></tr><tr><td>Test_RMSE</td><td>0.70056</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.00893</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.02865</td></tr><tr><td>val_loss</td><td>0.01309</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">clear-sweep-2</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/meztpwq4" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/meztpwq4</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_092751-meztpwq4/logs</code>
# wandb: Agent Starting Run: bggvg7fr with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_092816-bggvg7fr</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bggvg7fr" target="_blank">neat-sweep-3</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.390 MB of 1.390 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54158</td></tr><tr><td>Test_MAPE</td><td>0.15389</td></tr><tr><td>Test_MSE</td><td>0.46329</td></tr><tr><td>Test_RMSE</td><td>0.68065</td></tr><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.00859</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>0.33728</td></tr><tr><td>val_loss</td><td>0.03893</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">neat-sweep-3</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bggvg7fr" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bggvg7fr</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_092816-bggvg7fr/logs</code>
# wandb: Agent Starting Run: pwem3cu9 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 11
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_092847-pwem3cu9</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pwem3cu9" target="_blank">dandy-sweep-4</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.081 MB of 0.081 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▃▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▇▇▄█▁▃▂▁▃▂▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54764</td></tr><tr><td>Test_MAPE</td><td>0.15894</td></tr><tr><td>Test_MSE</td><td>0.47735</td></tr><tr><td>Test_RMSE</td><td>0.69091</td></tr><tr><td>best_epoch</td><td>23</td></tr><tr><td>best_val_loss</td><td>0.00882</td></tr><tr><td>epoch</td><td>33</td></tr><tr><td>loss</td><td>0.02281</td></tr><tr><td>val_loss</td><td>0.00911</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dandy-sweep-4</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pwem3cu9" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pwem3cu9</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_092847-pwem3cu9/logs</code>
# wandb: Agent Starting Run: h639qh9z with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 1
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_092913-h639qh9z</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/h639qh9z" target="_blank">atomic-sweep-5</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.615 MB of 0.615 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▆▂▃▂▂▂▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▆▄█▁▅▁▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.6455</td></tr><tr><td>Test_MAPE</td><td>0.2183</td></tr><tr><td>Test_MSE</td><td>0.65494</td></tr><tr><td>Test_RMSE</td><td>0.80929</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.0114</td></tr><tr><td>epoch</td><td>13</td></tr><tr><td>loss</td><td>0.75455</td></tr><tr><td>val_loss</td><td>0.77313</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">atomic-sweep-5</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/h639qh9z" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/h639qh9z</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_092913-h639qh9z/logs</code>
# wandb: Agent Starting Run: bw3rlhid with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 12
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_092933-bw3rlhid</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bw3rlhid" target="_blank">sleek-sweep-6</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.150 MB of 0.150 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>▂█▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54814</td></tr><tr><td>Test_MAPE</td><td>0.15681</td></tr><tr><td>Test_MSE</td><td>0.47023</td></tr><tr><td>Test_RMSE</td><td>0.68573</td></tr><tr><td>best_epoch</td><td>5</td></tr><tr><td>best_val_loss</td><td>0.00864</td></tr><tr><td>epoch</td><td>15</td></tr><tr><td>loss</td><td>0.02176</td></tr><tr><td>val_loss</td><td>0.00878</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sleek-sweep-6</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bw3rlhid" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bw3rlhid</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_092933-bw3rlhid/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: zd0vamn8 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 12
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093009-zd0vamn8</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/zd0vamn8" target="_blank">rural-sweep-7</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>▆█▃▄▃▂▂▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄▁█▃▃▃▂▃▂▂▁▂▁▂▁▂▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54592</td></tr><tr><td>Test_MAPE</td><td>0.15466</td></tr><tr><td>Test_MSE</td><td>0.46641</td></tr><tr><td>Test_RMSE</td><td>0.68294</td></tr><tr><td>best_epoch</td><td>14</td></tr><tr><td>best_val_loss</td><td>0.00864</td></tr><tr><td>epoch</td><td>24</td></tr><tr><td>loss</td><td>0.02232</td></tr><tr><td>val_loss</td><td>0.0132</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">rural-sweep-7</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/zd0vamn8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/zd0vamn8</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093009-zd0vamn8/logs</code>
# wandb: Agent Starting Run: jxy090fa with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 11
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093034-jxy090fa</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/jxy090fa" target="_blank">serene-sweep-8</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.947 MB of 2.947 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54792</td></tr><tr><td>Test_MAPE</td><td>0.15803</td></tr><tr><td>Test_MSE</td><td>0.47198</td></tr><tr><td>Test_RMSE</td><td>0.68701</td></tr><tr><td>best_epoch</td><td>16</td></tr><tr><td>best_val_loss</td><td>0.00863</td></tr><tr><td>epoch</td><td>26</td></tr><tr><td>loss</td><td>0.06812</td></tr><tr><td>val_loss</td><td>0.05978</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">serene-sweep-8</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/jxy090fa" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/jxy090fa</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093034-jxy090fa/logs</code>
# wandb: Agent Starting Run: kgnbr0ro with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 12
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093115-kgnbr0ro</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/kgnbr0ro" target="_blank">fearless-sweep-9</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▇▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>1.08113</td></tr><tr><td>Test_MAPE</td><td>0.46121</td></tr><tr><td>Test_MSE</td><td>2.46812</td></tr><tr><td>Test_RMSE</td><td>1.57102</td></tr><tr><td>best_epoch</td><td>8</td></tr><tr><td>best_val_loss</td><td>0.04278</td></tr><tr><td>epoch</td><td>18</td></tr><tr><td>loss</td><td>0.34901</td></tr><tr><td>val_loss</td><td>0.10267</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fearless-sweep-9</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/kgnbr0ro" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/kgnbr0ro</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093115-kgnbr0ro/logs</code>
# wandb: Agent Starting Run: gau4qb9j with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 10
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093156-gau4qb9j</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gau4qb9j" target="_blank">solar-sweep-10</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.399 MB of 0.399 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▂█▃▂▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54227</td></tr><tr><td>Test_MAPE</td><td>0.15416</td></tr><tr><td>Test_MSE</td><td>0.46329</td></tr><tr><td>Test_RMSE</td><td>0.68065</td></tr><tr><td>best_epoch</td><td>34</td></tr><tr><td>best_val_loss</td><td>0.00866</td></tr><tr><td>epoch</td><td>44</td></tr><tr><td>loss</td><td>0.02123</td></tr><tr><td>val_loss</td><td>0.00904</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">solar-sweep-10</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gau4qb9j" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gau4qb9j</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093156-gau4qb9j/logs</code>
# wandb: Agent Starting Run: 7xkxz31t with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 10
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093227-7xkxz31t</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/7xkxz31t" target="_blank">ancient-sweep-11</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.947 MB of 2.947 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▂▂█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁█▁▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54279</td></tr><tr><td>Test_MAPE</td><td>0.15496</td></tr><tr><td>Test_MSE</td><td>0.46496</td></tr><tr><td>Test_RMSE</td><td>0.68188</td></tr><tr><td>best_epoch</td><td>38</td></tr><tr><td>best_val_loss</td><td>0.00866</td></tr><tr><td>epoch</td><td>48</td></tr><tr><td>loss</td><td>0.02332</td></tr><tr><td>val_loss</td><td>0.00868</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ancient-sweep-11</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/7xkxz31t" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/7xkxz31t</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093227-7xkxz31t/logs</code>
# wandb: Agent Starting Run: bwhtszp2 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 11
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093313-bwhtszp2</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bwhtszp2" target="_blank">eternal-sweep-12</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.150 MB of 0.150 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>▃▅▂█▅▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄▁█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54822</td></tr><tr><td>Test_MAPE</td><td>0.15824</td></tr><tr><td>Test_MSE</td><td>0.4729</td></tr><tr><td>Test_RMSE</td><td>0.68768</td></tr><tr><td>best_epoch</td><td>14</td></tr><tr><td>best_val_loss</td><td>0.00864</td></tr><tr><td>epoch</td><td>24</td></tr><tr><td>loss</td><td>0.02498</td></tr><tr><td>val_loss</td><td>0.01675</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">eternal-sweep-12</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bwhtszp2" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bwhtszp2</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093313-bwhtszp2/logs</code>
# wandb: Agent Starting Run: ahf7dp1p with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 12
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093338-ahf7dp1p</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ahf7dp1p" target="_blank">northern-sweep-13</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.827 MB of 0.827 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54539</td></tr><tr><td>Test_MAPE</td><td>0.15314</td></tr><tr><td>Test_MSE</td><td>0.46435</td></tr><tr><td>Test_RMSE</td><td>0.68144</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.00868</td></tr><tr><td>epoch</td><td>12</td></tr><tr><td>loss</td><td>0.02489</td></tr><tr><td>val_loss</td><td>0.01297</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">northern-sweep-13</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ahf7dp1p" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ahf7dp1p</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093338-ahf7dp1p/logs</code>
# wandb: Agent Starting Run: 05ny3obn with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 5
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093419-05ny3obn</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/05ny3obn" target="_blank">radiant-sweep-14</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.390 MB of 1.390 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▄▁▁▃▃▁▁▁▁▁▂▁▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53873</td></tr><tr><td>Test_MAPE</td><td>0.15171</td></tr><tr><td>Test_MSE</td><td>0.45716</td></tr><tr><td>Test_RMSE</td><td>0.67614</td></tr><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.00861</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>0.30086</td></tr><tr><td>val_loss</td><td>0.01982</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">radiant-sweep-14</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/05ny3obn" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/05ny3obn</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093419-05ny3obn/logs</code>
# wandb: Agent Starting Run: 2kcl1biv with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093449-2kcl1biv</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/2kcl1biv" target="_blank">daily-sweep-15</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.947 MB of 2.947 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>▂█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54523</td></tr><tr><td>Test_MAPE</td><td>0.15752</td></tr><tr><td>Test_MSE</td><td>0.47182</td></tr><tr><td>Test_RMSE</td><td>0.68689</td></tr><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.00862</td></tr><tr><td>epoch</td><td>23</td></tr><tr><td>loss</td><td>0.03043</td></tr><tr><td>val_loss</td><td>0.01627</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">daily-sweep-15</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/2kcl1biv" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/2kcl1biv</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093449-2kcl1biv/logs</code>
# wandb: Agent Starting Run: z4aeeyhy with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 10
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093525-z4aeeyhy</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/z4aeeyhy" target="_blank">upbeat-sweep-16</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.827 MB of 0.827 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54222</td></tr><tr><td>Test_MAPE</td><td>0.15407</td></tr><tr><td>Test_MSE</td><td>0.4631</td></tr><tr><td>Test_RMSE</td><td>0.68051</td></tr><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.00866</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.07356</td></tr><tr><td>val_loss</td><td>0.05872</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">upbeat-sweep-16</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/z4aeeyhy" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/z4aeeyhy</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093525-z4aeeyhy/logs</code>
# wandb: Agent Starting Run: e2hwhagp with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093601-e2hwhagp</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/e2hwhagp" target="_blank">divine-sweep-17</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.399 MB of 0.399 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▃▂▂▁▁▁▁▁▂▃▃▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.56065</td></tr><tr><td>Test_MAPE</td><td>0.1463</td></tr><tr><td>Test_MSE</td><td>0.48475</td></tr><tr><td>Test_RMSE</td><td>0.69624</td></tr><tr><td>best_epoch</td><td>9</td></tr><tr><td>best_val_loss</td><td>0.00995</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.03581</td></tr><tr><td>val_loss</td><td>0.03448</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">divine-sweep-17</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/e2hwhagp" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/e2hwhagp</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093601-e2hwhagp/logs</code>
# wandb: Agent Starting Run: hh6punah with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 12
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093631-hh6punah</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/hh6punah" target="_blank">worthy-sweep-18</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.166 MB of 0.166 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>loss</td><td>▄█▆▁▁▁▁▂▂▂▁▂▃▄▃</td></tr><tr><td>val_loss</td><td>▇█▁▁▁▁▁▁▂▂▂▃▂▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.57537</td></tr><tr><td>Test_MAPE</td><td>0.17251</td></tr><tr><td>Test_MSE</td><td>0.52525</td></tr><tr><td>Test_RMSE</td><td>0.72474</td></tr><tr><td>best_epoch</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.00983</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>loss</td><td>0.71982</td></tr><tr><td>val_loss</td><td>0.02749</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">worthy-sweep-18</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/hh6punah" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/hh6punah</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_093631-hh6punah/logs</code>
# wandb: Agent Starting Run: 4vloahu3 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 8
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_093707-4vloahu3</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/4vloahu3" target="_blank">zany-sweep-19</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
# ...
# Synced <strong style="color:#cdcd00">exalted-sweep-94</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/47xqxh13" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/47xqxh13</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_102843-47xqxh13/logs</code>
# wandb: Agent Starting Run: 1f8vci25 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 11
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_102913-1f8vci25</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/1f8vci25" target="_blank">snowy-sweep-95</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂█▁▂▂▁▁▁▁▂▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.58404</td></tr><tr><td>Test_MAPE</td><td>0.18199</td></tr><tr><td>Test_MSE</td><td>0.54278</td></tr><tr><td>Test_RMSE</td><td>0.73674</td></tr><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.00955</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>loss</td><td>0.02428</td></tr><tr><td>val_loss</td><td>0.01612</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">snowy-sweep-95</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/1f8vci25" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/1f8vci25</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_102913-1f8vci25/logs</code>
# wandb: Agent Starting Run: eolh4fpy with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 8
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_102959-eolh4fpy</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/eolh4fpy" target="_blank">apricot-sweep-96</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54277</td></tr><tr><td>Test_MAPE</td><td>0.1545</td></tr><tr><td>Test_MSE</td><td>0.46559</td></tr><tr><td>Test_RMSE</td><td>0.68235</td></tr><tr><td>best_epoch</td><td>10</td></tr><tr><td>best_val_loss</td><td>0.00859</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>0.02299</td></tr><tr><td>val_loss</td><td>0.00859</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">apricot-sweep-96</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/eolh4fpy" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/eolh4fpy</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_102959-eolh4fpy/logs</code>
# wandb: Agent Starting Run: sa6vojla with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 10
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103041-sa6vojla</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/sa6vojla" target="_blank">glad-sweep-97</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='11.404 MB of 11.404 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▂▄▃▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.55515</td></tr><tr><td>Test_MAPE</td><td>0.14697</td></tr><tr><td>Test_MSE</td><td>0.47761</td></tr><tr><td>Test_RMSE</td><td>0.69109</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.00966</td></tr><tr><td>epoch</td><td>12</td></tr><tr><td>loss</td><td>0.02487</td></tr><tr><td>val_loss</td><td>0.01007</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">glad-sweep-97</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/sa6vojla" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/sa6vojla</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103041-sa6vojla/logs</code>
# wandb: Agent Starting Run: 2rv0oeum with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 8
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103133-2rv0oeum</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/2rv0oeum" target="_blank">honest-sweep-98</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='11.404 MB of 11.404 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54504</td></tr><tr><td>Test_MAPE</td><td>0.15677</td></tr><tr><td>Test_MSE</td><td>0.47084</td></tr><tr><td>Test_RMSE</td><td>0.68618</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.0086</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>0.04967</td></tr><tr><td>val_loss</td><td>0.03103</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">honest-sweep-98</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/2rv0oeum" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/2rv0oeum</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103133-2rv0oeum/logs</code>
# wandb: Agent Starting Run: nqhla161 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 11
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103243-nqhla161</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/nqhla161" target="_blank">proud-sweep-99</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='11.404 MB of 11.404 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54651</td></tr><tr><td>Test_MAPE</td><td>0.15664</td></tr><tr><td>Test_MSE</td><td>0.46936</td></tr><tr><td>Test_RMSE</td><td>0.6851</td></tr><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.00862</td></tr><tr><td>epoch</td><td>23</td></tr><tr><td>loss</td><td>0.02167</td></tr><tr><td>val_loss</td><td>0.00867</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">proud-sweep-99</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/nqhla161" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/nqhla161</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103243-nqhla161/logs</code>
# wandb: Agent Starting Run: pv2nku1n with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 11
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103355-pv2nku1n</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pv2nku1n" target="_blank">lemon-sweep-100</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/kgxsxnr8</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▆▃▂▂▁▂▄▇▇▆▄▃▃▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.55159</td></tr><tr><td>Test_MAPE</td><td>0.16102</td></tr><tr><td>Test_MSE</td><td>0.47981</td></tr><tr><td>Test_RMSE</td><td>0.69268</td></tr><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.00869</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>loss</td><td>0.02394</td></tr><tr><td>val_loss</td><td>0.01468</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">lemon-sweep-100</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pv2nku1n" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pv2nku1n</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103355-pv2nku1n/logs</code>

# %% [markdown]
# # LSTM

# %%
# Configure the sweep – specify the parameters to search through, the search strategy, the optimization metric et all.
sweep_config = {
    'name': 'LSTM',
    'method': 'bayes', #grid, random
    'metric': {
      'name': 'best_val_loss',
      'goal': 'minimize'   
    },
    'parameters': {
        'batch_size': {
            'values': [256, 128, 64, 32]
        },
        'dropout': {
            'values': [0, 0.1, 0.3]
        },
        'units': {
            'values': [32, 64, 128, 256]
        },
        'timestep': {
            'distribution': "int_uniform",
            'min': 1,
            'max': 12
        },
        'lr': {
            'values': [1e-2, 1e-1]
        },
        'layers': {
            'values': [1, 2, 4, 8]
        }
        
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, entity="ancy", project="FORTALEZA-2022-06-22-HYBRID")
# Out:
# Create sweep with ID: 1qiniy1v
# Sweep URL: https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v

# %%
def create_lstm():
    config_defaults = {
    'batch_size': 128,
    'lr': 1e-3,
    'units': 64,
    'timestep': 3,
    'dropout': 0.3,
    'layers': 1
    }

    wandb.init(config=config_defaults)
    config = wandb.config

    batch_size = config.batch_size
    lr         = config.lr
    num_units  = config.units
    timestep   = config.timestep
    dropout    = config.dropout
    layers     = config.layers

    train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y = make_data3(hourly, config.timestep, resid_check=True, resid=False, univariate=False)
    model = Sequential()

    if layers > 1:
      model.add(LSTM(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout, return_sequences=True))

      for i in range(layers-2):
        model.add(LSTM(units = num_units, dropout=dropout, return_sequences=True))

      model.add(LSTM(units = num_units, dropout=dropout))

    else:
      model.add(LSTM(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout))

    model.add(Dense(units = 1))
    model.compile(
        loss="mse",
        optimizer=Adam(learning_rate=lr)
    )

    model.fit(train_X, train_y, batch_size=batch_size,
              epochs=200, verbose=0, shuffle=False,
              validation_data=(valid_X, valid_y),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=10, restore_best_weights=True)])
    
    yhat = model.predict(test_X)
    yhat_inv = scaler_y.inverse_transform(yhat)
    resid_sum = (yhat_inv+sarima_pred.values[config.timestep:])
    resid_sum2 = (yhat_inv+sarima_pred2.values[config.timestep:])

    wandb.log({"Test_MSE": mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    wandb.log({"Test_RMSE": sqrt(mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y)))})

    wandb.log({"Test_MAE": mean_absolute_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    wandb.log({"Test_MAPE": mean_absolute_percentage_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    return model

# %%
wandb.agent(sweep_id, create_lstm, count=50)
# Out:
# wandb: Agent Starting Run: 4csmo6za with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 9
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103427-4csmo6za</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/4csmo6za" target="_blank">winter-sweep-1</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.960 MB of 2.960 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54887</td></tr><tr><td>Test_MAPE</td><td>0.16165</td></tr><tr><td>Test_MSE</td><td>0.48074</td></tr><tr><td>Test_RMSE</td><td>0.69336</td></tr><tr><td>best_epoch</td><td>5</td></tr><tr><td>best_val_loss</td><td>0.00884</td></tr><tr><td>epoch</td><td>15</td></tr><tr><td>loss</td><td>0.0216</td></tr><tr><td>val_loss</td><td>0.00917</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">winter-sweep-1</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/4csmo6za" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/4csmo6za</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103427-4csmo6za/logs</code>
# wandb: Agent Starting Run: ebn4cpgk with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103523-ebn4cpgk</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ebn4cpgk" target="_blank">hardy-sweep-2</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.619 MB of 0.619 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▆▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54024</td></tr><tr><td>Test_MAPE</td><td>0.15252</td></tr><tr><td>Test_MSE</td><td>0.46071</td></tr><tr><td>Test_RMSE</td><td>0.67875</td></tr><tr><td>best_epoch</td><td>16</td></tr><tr><td>best_val_loss</td><td>0.00865</td></tr><tr><td>epoch</td><td>26</td></tr><tr><td>loss</td><td>0.02229</td></tr><tr><td>val_loss</td><td>0.0087</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">hardy-sweep-2</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ebn4cpgk" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ebn4cpgk</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103523-ebn4cpgk/logs</code>
# wandb: Agent Starting Run: xi6vmba5 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	timestep: 10
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103554-xi6vmba5</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/xi6vmba5" target="_blank">dulcet-sweep-3</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.810 MB of 0.810 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.55671</td></tr><tr><td>Test_MAPE</td><td>0.16887</td></tr><tr><td>Test_MSE</td><td>0.49113</td></tr><tr><td>Test_RMSE</td><td>0.7008</td></tr><tr><td>best_epoch</td><td>9</td></tr><tr><td>best_val_loss</td><td>0.00902</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.02123</td></tr><tr><td>val_loss</td><td>0.00908</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dulcet-sweep-3</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/xi6vmba5" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/xi6vmba5</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103554-xi6vmba5/logs</code>
# wandb: Agent Starting Run: gxmq3g23 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 6
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103624-gxmq3g23</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gxmq3g23" target="_blank">cerulean-sweep-4</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.325 MB of 2.325 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54409</td></tr><tr><td>Test_MAPE</td><td>0.15613</td></tr><tr><td>Test_MSE</td><td>0.46812</td></tr><tr><td>Test_RMSE</td><td>0.6842</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.00859</td></tr><tr><td>epoch</td><td>12</td></tr><tr><td>loss</td><td>0.02408</td></tr><tr><td>val_loss</td><td>0.00999</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">cerulean-sweep-4</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gxmq3g23" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gxmq3g23</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103624-gxmq3g23/logs</code>
# wandb: Agent Starting Run: vle7puh2 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 2
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103655-vle7puh2</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/vle7puh2" target="_blank">apricot-sweep-5</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.362 MB of 5.362 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▂█▅▅▇▁▃▄▁▂▃▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▇▄█▂▃▄▁▂▃▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54649</td></tr><tr><td>Test_MAPE</td><td>0.14699</td></tr><tr><td>Test_MSE</td><td>0.46067</td></tr><tr><td>Test_RMSE</td><td>0.67872</td></tr><tr><td>best_epoch</td><td>28</td></tr><tr><td>best_val_loss</td><td>0.00951</td></tr><tr><td>epoch</td><td>38</td></tr><tr><td>loss</td><td>0.02756</td></tr><tr><td>val_loss</td><td>0.01165</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">apricot-sweep-5</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/vle7puh2" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/vle7puh2</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103655-vle7puh2/logs</code>
# wandb: Agent Starting Run: huvp97wz with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103736-huvp97wz</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/huvp97wz" target="_blank">colorful-sweep-6</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='9.112 MB of 9.112 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54545</td></tr><tr><td>Test_MAPE</td><td>0.1577</td></tr><tr><td>Test_MSE</td><td>0.47227</td></tr><tr><td>Test_RMSE</td><td>0.68722</td></tr><tr><td>best_epoch</td><td>21</td></tr><tr><td>best_val_loss</td><td>0.00862</td></tr><tr><td>epoch</td><td>31</td></tr><tr><td>loss</td><td>0.02715</td></tr><tr><td>val_loss</td><td>0.01007</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">colorful-sweep-6</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/huvp97wz" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/huvp97wz</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103736-huvp97wz/logs</code>
# wandb: Agent Starting Run: gkjtnc0p with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 5
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103842-gkjtnc0p</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gkjtnc0p" target="_blank">swift-sweep-7</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.325 MB of 2.325 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▂▂▁▁▁▁▂▂▂▂▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.60385</td></tr><tr><td>Test_MAPE</td><td>0.1923</td></tr><tr><td>Test_MSE</td><td>0.58118</td></tr><tr><td>Test_RMSE</td><td>0.76235</td></tr><tr><td>best_epoch</td><td>5</td></tr><tr><td>best_val_loss</td><td>0.01021</td></tr><tr><td>epoch</td><td>15</td></tr><tr><td>loss</td><td>0.12063</td></tr><tr><td>val_loss</td><td>0.04708</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">swift-sweep-7</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gkjtnc0p" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gkjtnc0p</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103842-gkjtnc0p/logs</code>
# wandb: Agent Starting Run: l05o9otn with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 9
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103917-l05o9otn</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/l05o9otn" target="_blank">flowing-sweep-8</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.189 MB of 0.189 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▃▃▁▁▂▃▃▃▃▄▄▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.5789</td></tr><tr><td>Test_MAPE</td><td>0.17978</td></tr><tr><td>Test_MSE</td><td>0.53631</td></tr><tr><td>Test_RMSE</td><td>0.73233</td></tr><tr><td>best_epoch</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.00966</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>loss</td><td>0.03188</td></tr><tr><td>val_loss</td><td>0.01456</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">flowing-sweep-8</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/l05o9otn" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/l05o9otn</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103917-l05o9otn/logs</code>
# wandb: Agent Starting Run: uas8kfov with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 3
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_103948-uas8kfov</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/uas8kfov" target="_blank">dauntless-sweep-9</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54075</td></tr><tr><td>Test_MAPE</td><td>0.15578</td></tr><tr><td>Test_MSE</td><td>0.46197</td></tr><tr><td>Test_RMSE</td><td>0.67968</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.00864</td></tr><tr><td>epoch</td><td>13</td></tr><tr><td>loss</td><td>0.02582</td></tr><tr><td>val_loss</td><td>0.00866</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dauntless-sweep-9</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/uas8kfov" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/uas8kfov</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_103948-uas8kfov/logs</code>
# wandb: Agent Starting Run: 4c434bly with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 8
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_104039-4c434bly</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/4c434bly" target="_blank">polar-sweep-10</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.960 MB of 2.960 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54166</td></tr><tr><td>Test_MAPE</td><td>0.15234</td></tr><tr><td>Test_MSE</td><td>0.46111</td></tr><tr><td>Test_RMSE</td><td>0.67905</td></tr><tr><td>best_epoch</td><td>5</td></tr><tr><td>best_val_loss</td><td>0.00861</td></tr><tr><td>epoch</td><td>15</td></tr><tr><td>loss</td><td>0.03665</td></tr><tr><td>val_loss</td><td>0.02007</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">polar-sweep-10</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/4c434bly" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/4c434bly</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_104039-4c434bly/logs</code>
# wandb: Agent Starting Run: 2lhq4hkq with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 2
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_104140-2lhq4hkq</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/2lhq4hkq" target="_blank">crimson-sweep-11</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.404 MB of 0.404 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>██▁▆▃▅▄▅▅▅▅▆▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53765</td></tr><tr><td>Test_MAPE</td><td>0.14942</td></tr><tr><td>Test_MSE</td><td>0.45115</td></tr><tr><td>Test_RMSE</td><td>0.67168</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.00891</td></tr><tr><td>epoch</td><td>12</td></tr><tr><td>loss</td><td>0.02505</td></tr><tr><td>val_loss</td><td>0.00914</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">crimson-sweep-11</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/2lhq4hkq" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/2lhq4hkq</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_104140-2lhq4hkq/logs</code>
# wandb: Agent Starting Run: mx9k25o8 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 6
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_104216-mx9k25o8</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/mx9k25o8" target="_blank">jolly-sweep-12</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.362 MB of 5.362 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▄▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54078</td></tr><tr><td>Test_MAPE</td><td>0.15206</td></tr><tr><td>Test_MSE</td><td>0.45889</td></tr><tr><td>Test_RMSE</td><td>0.67741</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.00861</td></tr><tr><td>epoch</td><td>13</td></tr><tr><td>loss</td><td>0.02319</td></tr><tr><td>val_loss</td><td>0.00879</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">jolly-sweep-12</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/mx9k25o8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/mx9k25o8</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_104216-mx9k25o8/logs</code>
# wandb: Agent Starting Run: 8bwzjqin with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 9
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_104256-8bwzjqin</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/8bwzjqin" target="_blank">confused-sweep-13</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.619 MB of 0.619 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▄▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▃▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54773</td></tr><tr><td>Test_MAPE</td><td>0.15993</td></tr><tr><td>Test_MSE</td><td>0.47144</td></tr><tr><td>Test_RMSE</td><td>0.68661</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.009</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>0.02063</td></tr><tr><td>val_loss</td><td>0.00978</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">confused-sweep-13</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/8bwzjqin" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/8bwzjqin</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_104256-8bwzjqin/logs</code>
# wandb: Agent Starting Run: pzlm3fye with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	timestep: 4
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_104327-pzlm3fye</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pzlm3fye" target="_blank">unique-sweep-14</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.091 MB of 3.091 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂█▃▁▂▂▁▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54169</td></tr><tr><td>Test_MAPE</td><td>0.15784</td></tr><tr><td>Test_MSE</td><td>0.47476</td></tr><tr><td>Test_RMSE</td><td>0.68903</td></tr><tr><td>best_epoch</td><td>24</td></tr><tr><td>best_val_loss</td><td>0.00965</td></tr><tr><td>epoch</td><td>34</td></tr><tr><td>loss</td><td>0.02201</td></tr><tr><td>val_loss</td><td>0.01014</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">unique-sweep-14</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pzlm3fye" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pzlm3fye</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_104327-pzlm3fye/logs</code>
# wandb: Agent Starting Run: cybp93mu with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	timestep: 1
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_104403-cybp93mu</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/cybp93mu" target="_blank">noble-sweep-15</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.083 MB of 0.083 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▄██▅▂▁▁▁▁▁▁▁▁▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54454</td></tr><tr><td>Test_MAPE</td><td>0.1623</td></tr><tr><td>Test_MSE</td><td>0.47895</td></tr><tr><td>Test_RMSE</td><td>0.69206</td></tr><tr><td>best_epoch</td><td>23</td></tr><tr><td>best_val_loss</td><td>0.00969</td></tr><tr><td>epoch</td><td>33</td></tr><tr><td>loss</td><td>0.02381</td></tr><tr><td>val_loss</td><td>0.01018</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">noble-sweep-15</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/cybp93mu" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/cybp93mu</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_104403-cybp93mu/logs</code>
# wandb: Agent Starting Run: 5oce3qeq with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 1
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_104428-5oce3qeq</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/5oce3qeq" target="_blank">sparkling-sweep-16</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.960 MB of 2.960 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.5382</td></tr><tr><td>Test_MAPE</td><td>0.15614</td></tr><tr><td>Test_MSE</td><td>0.46001</td></tr><tr><td>Test_RMSE</td><td>0.67824</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.00866</td></tr><tr><td>epoch</td><td>13</td></tr><tr><td>loss</td><td>0.0266</td></tr><tr><td>val_loss</td><td>0.00877</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sparkling-sweep-16</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/5oce3qeq" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/5oce3qeq</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_104428-5oce3qeq/logs</code>
# wandb: Agent Starting Run: 4uqjrjrc with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_104519-4uqjrjrc</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/4uqjrjrc" target="_blank">classic-sweep-17</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='21.161 MB of 21.161 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54378</td></tr><tr><td>Test_MAPE</td><td>0.14729</td></tr><tr><td>Test_MSE</td><td>0.45993</td></tr><tr><td>Test_RMSE</td><td>0.67818</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.009</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>0.03372</td></tr><tr><td>val_loss</td><td>0.04137</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">classic-sweep-17</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/4uqjrjrc" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/4uqjrjrc</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_104519-4uqjrjrc/logs</code>
# wandb: Agent Starting Run: wlw3j2xd with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_104636-wlw3j2xd</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/wlw3j2xd" target="_blank">solar-sweep-18</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='21.161 MB of 21.161 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄▁▂▁▁▂▃▄▄▄▂▁▁▄▅▇█▇▆▄▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.57495</td></tr><tr><td>Test_MAPE</td><td>0.17677</td></tr><tr><td>Test_MSE</td><td>0.5289</td></tr><tr><td>Test_RMSE</td><td>0.72725</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.00935</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>0.04242</td></tr><tr><td>val_loss</td><td>0.02438</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">solar-sweep-18</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/wlw3j2xd" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/wlw3j2xd</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_104636-wlw3j2xd/logs</code>
# wandb: Agent Starting Run: rjb3du01 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 8
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_104828-rjb3du01</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/rjb3du01" target="_blank">polished-sweep-19</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='21.161 MB of 21.161 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
# Synced <strong style="color:#cdcd00">clear-sweep-44</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ogb1c56p" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ogb1c56p</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_111221-ogb1c56p/logs</code>
# wandb: Agent Starting Run: lyzzc8eb with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 9
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_111337-lyzzc8eb</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/lyzzc8eb" target="_blank">earnest-sweep-45</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='9.112 MB of 9.112 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53938</td></tr><tr><td>Test_MAPE</td><td>0.15258</td></tr><tr><td>Test_MSE</td><td>0.45917</td></tr><tr><td>Test_RMSE</td><td>0.67762</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.00869</td></tr><tr><td>epoch</td><td>29</td></tr><tr><td>loss</td><td>0.02186</td></tr><tr><td>val_loss</td><td>0.00926</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">earnest-sweep-45</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/lyzzc8eb" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/lyzzc8eb</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_111337-lyzzc8eb/logs</code>
# wandb: Agent Starting Run: iaw52ffk with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 4
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_111428-iaw52ffk</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/iaw52ffk" target="_blank">magic-sweep-46</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.960 MB of 2.960 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▄▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▆▁█▂▄▇▁▁▂▄▂▁▁▃▂▁▁▂▂▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53806</td></tr><tr><td>Test_MAPE</td><td>0.15259</td></tr><tr><td>Test_MSE</td><td>0.45795</td></tr><tr><td>Test_RMSE</td><td>0.67672</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.00863</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>0.02334</td></tr><tr><td>val_loss</td><td>0.01018</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">magic-sweep-46</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/iaw52ffk" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/iaw52ffk</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_111428-iaw52ffk/logs</code>
# wandb: Agent Starting Run: 58y0gzbt with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 11
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_111529-58y0gzbt</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/58y0gzbt" target="_blank">elated-sweep-47</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.960 MB of 2.960 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▄▇█▇▆▅▅▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.55068</td></tr><tr><td>Test_MAPE</td><td>0.14794</td></tr><tr><td>Test_MSE</td><td>0.47038</td></tr><tr><td>Test_RMSE</td><td>0.68584</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.00929</td></tr><tr><td>epoch</td><td>12</td></tr><tr><td>loss</td><td>0.11755</td></tr><tr><td>val_loss</td><td>0.01641</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">elated-sweep-47</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/58y0gzbt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/58y0gzbt</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_111529-58y0gzbt/logs</code>
# wandb: Agent Starting Run: u8rfqdxf with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	timestep: 1
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_111625-u8rfqdxf</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/u8rfqdxf" target="_blank">easy-sweep-48</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.083 MB of 0.083 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▄▂▂▂▂▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▃▅▆▄▂▁▁▁▁▁▁▁▁▂▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.5577</td></tr><tr><td>Test_MAPE</td><td>0.17461</td></tr><tr><td>Test_MSE</td><td>0.49688</td></tr><tr><td>Test_RMSE</td><td>0.7049</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.00919</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.02406</td></tr><tr><td>val_loss</td><td>0.00959</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">easy-sweep-48</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/u8rfqdxf" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/u8rfqdxf</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_111625-u8rfqdxf/logs</code>
# wandb: Agent Starting Run: d69thekq with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 12
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_111651-d69thekq</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/d69thekq" target="_blank">wandering-sweep-49</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.832 MB of 0.832 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>▆▂█▃▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54743</td></tr><tr><td>Test_MAPE</td><td>0.157</td></tr><tr><td>Test_MSE</td><td>0.47113</td></tr><tr><td>Test_RMSE</td><td>0.68639</td></tr><tr><td>best_epoch</td><td>20</td></tr><tr><td>best_val_loss</td><td>0.00863</td></tr><tr><td>epoch</td><td>30</td></tr><tr><td>loss</td><td>0.02021</td></tr><tr><td>val_loss</td><td>0.00971</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">wandering-sweep-49</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/d69thekq" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/d69thekq</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_111651-d69thekq/logs</code>
# wandb: Agent Starting Run: 44vqwf5i with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 32
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_111747-44vqwf5i</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/44vqwf5i" target="_blank">major-sweep-50</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/1qiniy1v</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.264 MB of 0.264 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▅▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54114</td></tr><tr><td>Test_MAPE</td><td>0.15306</td></tr><tr><td>Test_MSE</td><td>0.46146</td></tr><tr><td>Test_RMSE</td><td>0.67931</td></tr><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.00859</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.02182</td></tr><tr><td>val_loss</td><td>0.00921</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">major-sweep-50</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/44vqwf5i" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/44vqwf5i</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_111747-44vqwf5i/logs</code>

# %% [markdown]
# # GRU

# %%
# Configure the sweep – specify the parameters to search through, the search strategy, the optimization metric et all.
sweep_config = {
    'name': 'GRU',
    'method': 'bayes', #grid, random
    'metric': {
      'name': 'best_val_loss',
      'goal': 'minimize'   
    },
    'parameters': {
        'batch_size': {
            'values': [256, 128, 64, 32]
        },
        'dropout': {
            'values': [0, 0.1, 0.3]
        },
        'units': {
            'values': [64, 128, 256]
        },
        'timestep': {
            'distribution': "int_uniform",
            'min': 1,
            'max': 12
        },
        'lr': {
            'values': [1e-2, 1e-1]
        },
        'layers': {
            'values': [1, 2, 4, 8]
        },
        
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, entity="ancy", project="FORTALEZA-2022-06-22-HYBRID")
# Out:
# Create sweep with ID: 13ct2gwt
# Sweep URL: https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt

# %%
def create_gru():
    config_defaults = {
    'batch_size': 128,
    'lr': 1e-3,
    'units': 64,
    'timestep': 3,
    'dropout': 0.3,
    'layers': 1,
    }

    wandb.init(config=config_defaults)
    config = wandb.config

    batch_size = config.batch_size
    lr         = config.lr
    num_units  = config.units
    timestep   = config.timestep
    dropout    = config.dropout
    layers     = config.layers

    train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y = make_data3(hourly, config.timestep, resid_check=True, resid=False, univariate=False)
    model = Sequential()

    if layers > 1:
      model.add(GRU(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout, return_sequences=True))

      for i in range(layers-2):
        model.add(GRU(units = num_units, dropout=dropout, return_sequences=True))

      model.add(GRU(units = num_units, dropout=dropout))

    else:
      model.add(GRU(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout))

    model.add(Dense(units = 1))
    lr = config.lr
    model.compile(
        loss="mse",
        optimizer=Adam(learning_rate=lr)
    )
    
    model.fit(train_X, train_y, batch_size=config.batch_size,
              epochs=200, verbose=0, shuffle=False,
              validation_data=(valid_X, valid_y),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=10, restore_best_weights=True), ReduceLROnPlateau(monitor='val_loss',patience=5, min_lr=1e-6)])
    
    yhat = model.predict(test_X)
    yhat_inv = scaler_y.inverse_transform(yhat)
    resid_sum = (yhat_inv+sarima_pred.values[config.timestep:])
    resid_sum2 = (yhat_inv+sarima_pred2.values[config.timestep:])

    wandb.log({"Test_MSE": mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    wandb.log({"Test_RMSE": sqrt(mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y)))})

    wandb.log({"Test_MAE": mean_absolute_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    wandb.log({"Test_MAPE": mean_absolute_percentage_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    return model

# %%
wandb.agent(sweep_id, create_gru, count=50)
# Out:
# wandb: Agent Starting Run: t2feu6oy with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 6
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083528-t2feu6oy</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/t2feu6oy" target="_blank">ethereal-sweep-1</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.480 MB of 0.480 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54225</td></tr><tr><td>Test_MAPE</td><td>0.15279</td></tr><tr><td>Test_MSE</td><td>0.46083</td></tr><tr><td>Test_RMSE</td><td>0.67885</td></tr><tr><td>best_epoch</td><td>10</td></tr><tr><td>best_val_loss</td><td>0.0086</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>0.02207</td></tr><tr><td>val_loss</td><td>0.00948</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ethereal-sweep-1</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/t2feu6oy" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/t2feu6oy</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083528-t2feu6oy/logs</code>
# wandb: Agent Starting Run: z7p71zw3 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 2
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083558-z7p71zw3</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/z7p71zw3" target="_blank">glorious-sweep-2</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='11.361 MB of 11.361 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>▁█▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53699</td></tr><tr><td>Test_MAPE</td><td>0.15236</td></tr><tr><td>Test_MSE</td><td>0.45334</td></tr><tr><td>Test_RMSE</td><td>0.67331</td></tr><tr><td>best_epoch</td><td>8</td></tr><tr><td>best_val_loss</td><td>0.00871</td></tr><tr><td>epoch</td><td>18</td></tr><tr><td>loss</td><td>0.02364</td></tr><tr><td>val_loss</td><td>0.0112</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">glorious-sweep-2</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/z7p71zw3" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/z7p71zw3</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083558-z7p71zw3/logs</code>
# wandb: Agent Starting Run: 8pczza92 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 1
# wandb: 	lr: 0.1
# wandb: 	timestep: 12
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083654-8pczza92</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/8pczza92" target="_blank">playful-sweep-3</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▇▆▂▂▁▄▆█▆▇▃▁▁▁▂▂▂▂▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.60765</td></tr><tr><td>Test_MAPE</td><td>0.19998</td></tr><tr><td>Test_MSE</td><td>0.57336</td></tr><tr><td>Test_RMSE</td><td>0.7572</td></tr><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.00998</td></tr><tr><td>epoch</td><td>23</td></tr><tr><td>loss</td><td>0.02083</td></tr><tr><td>val_loss</td><td>0.01111</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">playful-sweep-3</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/8pczza92" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/8pczza92</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083654-8pczza92/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: ldker00o with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 9
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083730-ldker00o</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ldker00o" target="_blank">sweet-sweep-4</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.294 MB of 2.294 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.55119</td></tr><tr><td>Test_MAPE</td><td>0.16418</td></tr><tr><td>Test_MSE</td><td>0.48141</td></tr><tr><td>Test_RMSE</td><td>0.69384</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.00929</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>0.02061</td></tr><tr><td>val_loss</td><td>0.01014</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sweet-sweep-4</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ldker00o" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ldker00o</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083730-ldker00o/logs</code>
# wandb: Agent Starting Run: wczerb6q with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 9
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083838-wczerb6q</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/wczerb6q" target="_blank">glamorous-sweep-5</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.078 MB of 1.078 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>▆█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54052</td></tr><tr><td>Test_MAPE</td><td>0.15506</td></tr><tr><td>Test_MSE</td><td>0.46462</td></tr><tr><td>Test_RMSE</td><td>0.68163</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.00898</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.02143</td></tr><tr><td>val_loss</td><td>0.00979</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">glamorous-sweep-5</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/wczerb6q" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/wczerb6q</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083838-wczerb6q/logs</code>
# wandb: Agent Starting Run: j1cyey4a with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 9
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083915-j1cyey4a</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/j1cyey4a" target="_blank">ethereal-sweep-6</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='15.923 MB of 15.923 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54495</td></tr><tr><td>Test_MAPE</td><td>0.14833</td></tr><tr><td>Test_MSE</td><td>0.46214</td></tr><tr><td>Test_RMSE</td><td>0.67981</td></tr><tr><td>best_epoch</td><td>114</td></tr><tr><td>best_val_loss</td><td>0.00904</td></tr><tr><td>epoch</td><td>124</td></tr><tr><td>loss</td><td>0.0327</td></tr><tr><td>val_loss</td><td>0.00904</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ethereal-sweep-6</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/j1cyey4a" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/j1cyey4a</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083915-j1cyey4a/logs</code>
# wandb: Agent Starting Run: 6aikoron with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 10
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_084208-6aikoron</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/6aikoron" target="_blank">youthful-sweep-7</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.638 MB of 8.638 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▃▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▅▂▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.5433</td></tr><tr><td>Test_MAPE</td><td>0.15485</td></tr><tr><td>Test_MSE</td><td>0.46598</td></tr><tr><td>Test_RMSE</td><td>0.68263</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.0087</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.02917</td></tr><tr><td>val_loss</td><td>0.01037</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">youthful-sweep-7</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/6aikoron" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/6aikoron</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_084208-6aikoron/logs</code>
# wandb: Agent Starting Run: hdzzvdlx with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 12
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_084329-hdzzvdlx</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/hdzzvdlx" target="_blank">noble-sweep-8</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='34.040 MB of 34.040 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54598</td></tr><tr><td>Test_MAPE</td><td>0.15484</td></tr><tr><td>Test_MSE</td><td>0.46672</td></tr><tr><td>Test_RMSE</td><td>0.68317</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.00864</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.07201</td></tr><tr><td>val_loss</td><td>0.02336</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">noble-sweep-8</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/hdzzvdlx" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/hdzzvdlx</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_084329-hdzzvdlx/logs</code>
# wandb: Agent Starting Run: 48hbxs35 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 5
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_084536-48hbxs35</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/48hbxs35" target="_blank">dark-sweep-9</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.763 MB of 1.763 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54235</td></tr><tr><td>Test_MAPE</td><td>0.15609</td></tr><tr><td>Test_MSE</td><td>0.46737</td></tr><tr><td>Test_RMSE</td><td>0.68364</td></tr><tr><td>best_epoch</td><td>10</td></tr><tr><td>best_val_loss</td><td>0.00861</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>0.02261</td></tr><tr><td>val_loss</td><td>0.01005</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dark-sweep-9</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/48hbxs35" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/48hbxs35</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_084536-48hbxs35/logs</code>
# wandb: Agent Starting Run: sbmwt42n with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 3
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_084612-sbmwt42n</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/sbmwt42n" target="_blank">sleek-sweep-10</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.056 MB of 4.056 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53978</td></tr><tr><td>Test_MAPE</td><td>0.15406</td></tr><tr><td>Test_MSE</td><td>0.45808</td></tr><tr><td>Test_RMSE</td><td>0.67682</td></tr><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.00866</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>0.02453</td></tr><tr><td>val_loss</td><td>0.00957</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sleek-sweep-10</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/sbmwt42n" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/sbmwt42n</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_084612-sbmwt42n/logs</code>
# wandb: Agent Starting Run: ny0hjv78 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 6
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_084653-ny0hjv78</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ny0hjv78" target="_blank">zesty-sweep-11</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.638 MB of 8.638 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54199</td></tr><tr><td>Test_MAPE</td><td>0.15404</td></tr><tr><td>Test_MSE</td><td>0.46323</td></tr><tr><td>Test_RMSE</td><td>0.68061</td></tr><tr><td>best_epoch</td><td>18</td></tr><tr><td>best_val_loss</td><td>0.00858</td></tr><tr><td>epoch</td><td>28</td></tr><tr><td>loss</td><td>0.02197</td></tr><tr><td>val_loss</td><td>0.00982</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">zesty-sweep-11</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ny0hjv78" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ny0hjv78</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_084653-ny0hjv78/logs</code>
# wandb: Agent Starting Run: codqwipd with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 2
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_084814-codqwipd</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/codqwipd" target="_blank">frosty-sweep-12</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.638 MB of 8.638 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▄▄▅▅▆▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▄▃▃▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53776</td></tr><tr><td>Test_MAPE</td><td>0.14966</td></tr><tr><td>Test_MSE</td><td>0.45111</td></tr><tr><td>Test_RMSE</td><td>0.67165</td></tr><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.00887</td></tr><tr><td>epoch</td><td>11</td></tr><tr><td>loss</td><td>0.02389</td></tr><tr><td>val_loss</td><td>0.01067</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">frosty-sweep-12</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/codqwipd" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/codqwipd</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_084814-codqwipd/logs</code>
# wandb: Agent Starting Run: rm7huqci with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 9
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_084905-rm7huqci</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/rm7huqci" target="_blank">copper-sweep-13</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.056 MB of 4.056 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53977</td></tr><tr><td>Test_MAPE</td><td>0.15357</td></tr><tr><td>Test_MSE</td><td>0.46111</td></tr><tr><td>Test_RMSE</td><td>0.67905</td></tr><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.00868</td></tr><tr><td>epoch</td><td>23</td></tr><tr><td>loss</td><td>0.021</td></tr><tr><td>val_loss</td><td>0.00947</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">copper-sweep-13</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/rm7huqci" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/rm7huqci</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_084905-rm7huqci/logs</code>
# wandb: Agent Starting Run: m342dkar with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 4
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_084959-m342dkar</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/m342dkar" target="_blank">expert-sweep-14</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.731 MB of 0.731 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53975</td></tr><tr><td>Test_MAPE</td><td>0.15461</td></tr><tr><td>Test_MSE</td><td>0.46266</td></tr><tr><td>Test_RMSE</td><td>0.68019</td></tr><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.00863</td></tr><tr><td>epoch</td><td>23</td></tr><tr><td>loss</td><td>0.02275</td></tr><tr><td>val_loss</td><td>0.01017</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">expert-sweep-14</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/m342dkar" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/m342dkar</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_084959-m342dkar/logs</code>
# wandb: Agent Starting Run: pwdmbti8 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 8
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_085040-pwdmbti8</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pwdmbti8" target="_blank">lively-sweep-15</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.272 MB of 2.272 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54291</td></tr><tr><td>Test_MAPE</td><td>0.15467</td></tr><tr><td>Test_MSE</td><td>0.46599</td></tr><tr><td>Test_RMSE</td><td>0.68263</td></tr><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.00859</td></tr><tr><td>epoch</td><td>23</td></tr><tr><td>loss</td><td>0.02118</td></tr><tr><td>val_loss</td><td>0.00967</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">lively-sweep-15</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pwdmbti8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pwdmbti8</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_085040-pwdmbti8/logs</code>
# wandb: Agent Starting Run: dg435b56 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 3
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_085136-dg435b56</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/dg435b56" target="_blank">wandering-sweep-16</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.763 MB of 1.763 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54294</td></tr><tr><td>Test_MAPE</td><td>0.15805</td></tr><tr><td>Test_MSE</td><td>0.4673</td></tr><tr><td>Test_RMSE</td><td>0.6836</td></tr><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.00864</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.02302</td></tr><tr><td>val_loss</td><td>0.01032</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">wandering-sweep-16</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/dg435b56" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/dg435b56</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_085136-dg435b56/logs</code>
# wandb: Agent Starting Run: 0a90kliz with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 9
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_085212-0a90kliz</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/0a90kliz" target="_blank">twilight-sweep-17</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.638 MB of 8.638 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▂▂▁▂▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54009</td></tr><tr><td>Test_MAPE</td><td>0.14836</td></tr><tr><td>Test_MSE</td><td>0.45724</td></tr><tr><td>Test_RMSE</td><td>0.6762</td></tr><tr><td>best_epoch</td><td>16</td></tr><tr><td>best_val_loss</td><td>0.00891</td></tr><tr><td>epoch</td><td>26</td></tr><tr><td>loss</td><td>0.02097</td></tr><tr><td>val_loss</td><td>0.00967</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">twilight-sweep-17</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/0a90kliz" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/0a90kliz</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_085212-0a90kliz/logs</code>
# wandb: Agent Starting Run: dpg3fc1i with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 10
# wandb: 	units: 64
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_085324-dpg3fc1i</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/dpg3fc1i" target="_blank">crisp-sweep-18</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.078 MB of 1.078 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▇▄▆▆▄▃▂▂▂▁▁▁▁▁▁▁▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54341</td></tr><tr><td>Test_MAPE</td><td>0.15572</td></tr><tr><td>Test_MSE</td><td>0.46662</td></tr><tr><td>Test_RMSE</td><td>0.68309</td></tr><tr><td>best_epoch</td><td>14</td></tr><tr><td>best_val_loss</td><td>0.00866</td></tr><tr><td>epoch</td><td>24</td></tr><tr><td>loss</td><td>0.02147</td></tr><tr><td>val_loss</td><td>0.00895</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">crisp-sweep-18</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/dpg3fc1i" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/dpg3fc1i</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_085324-dpg3fc1i/logs</code>
# wandb: Agent Starting Run: pw5ilvxr with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 128
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_085406-pw5ilvxr</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/pw5ilvxr" target="_blank">splendid-sweep-19</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.056 MB of 4.056 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
# ...
# Synced <strong style="color:#cdcd00">decent-sweep-44</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/beucvxaz" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/beucvxaz</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_091606-beucvxaz/logs</code>
# wandb: Agent Starting Run: 46c2pvkc with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 5
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_091647-46c2pvkc</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/46c2pvkc" target="_blank">sage-sweep-45</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='15.923 MB of 15.923 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▆█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54261</td></tr><tr><td>Test_MAPE</td><td>0.1563</td></tr><tr><td>Test_MSE</td><td>0.46792</td></tr><tr><td>Test_RMSE</td><td>0.68405</td></tr><tr><td>best_epoch</td><td>14</td></tr><tr><td>best_val_loss</td><td>0.00861</td></tr><tr><td>epoch</td><td>24</td></tr><tr><td>loss</td><td>0.0232</td></tr><tr><td>val_loss</td><td>0.01059</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sage-sweep-45</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/46c2pvkc" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/46c2pvkc</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_091647-46c2pvkc/logs</code>
# wandb: Agent Starting Run: rx7vpwnj with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 6
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_091758-rx7vpwnj</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/rx7vpwnj" target="_blank">fine-sweep-46</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='34.040 MB of 34.040 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54314</td></tr><tr><td>Test_MAPE</td><td>0.15528</td></tr><tr><td>Test_MSE</td><td>0.46609</td></tr><tr><td>Test_RMSE</td><td>0.68271</td></tr><tr><td>best_epoch</td><td>16</td></tr><tr><td>best_val_loss</td><td>0.00858</td></tr><tr><td>epoch</td><td>26</td></tr><tr><td>loss</td><td>0.02239</td></tr><tr><td>val_loss</td><td>0.00974</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fine-sweep-46</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/rx7vpwnj" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/rx7vpwnj</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_091758-rx7vpwnj/logs</code>
# wandb: Agent Starting Run: dqmv65s5 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 8
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_092001-dqmv65s5</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/dqmv65s5" target="_blank">peach-sweep-47</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='15.923 MB of 15.923 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▄▅▅▆▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁█▆▁▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.6466</td></tr><tr><td>Test_MAPE</td><td>0.15664</td></tr><tr><td>Test_MSE</td><td>0.64115</td></tr><tr><td>Test_RMSE</td><td>0.80072</td></tr><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>0.01438</td></tr><tr><td>epoch</td><td>10</td></tr><tr><td>loss</td><td>0.05159</td></tr><tr><td>val_loss</td><td>0.02562</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">peach-sweep-47</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/dqmv65s5" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/dqmv65s5</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_092001-dqmv65s5/logs</code>
# wandb: Agent Starting Run: fro9gogz with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 9
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_092048-fro9gogz</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/fro9gogz" target="_blank">pretty-sweep-48</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='34.040 MB of 34.040 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▇▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.56385</td></tr><tr><td>Test_MAPE</td><td>0.1645</td></tr><tr><td>Test_MSE</td><td>0.49389</td></tr><tr><td>Test_RMSE</td><td>0.70278</td></tr><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.00899</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>loss</td><td>0.21503</td></tr><tr><td>val_loss</td><td>0.02812</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">pretty-sweep-48</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/fro9gogz" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/fro9gogz</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_092048-fro9gogz/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 5bmp5675 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_092219-5bmp5675</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/5bmp5675" target="_blank">resilient-sweep-49</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='15.923 MB of 15.923 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54618</td></tr><tr><td>Test_MAPE</td><td>0.15831</td></tr><tr><td>Test_MSE</td><td>0.47386</td></tr><tr><td>Test_RMSE</td><td>0.68837</td></tr><tr><td>best_epoch</td><td>16</td></tr><tr><td>best_val_loss</td><td>0.00864</td></tr><tr><td>epoch</td><td>26</td></tr><tr><td>loss</td><td>0.0216</td></tr><tr><td>val_loss</td><td>0.00978</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">resilient-sweep-49</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/5bmp5675" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/5bmp5675</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_092219-5bmp5675/logs</code>
# wandb: Agent Starting Run: ytsyan91 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 8
# wandb: 	units: 256
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_092325-ytsyan91</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ytsyan91" target="_blank">magic-sweep-50</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/13ct2gwt</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='15.923 MB of 15.923 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄▄██▅▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54373</td></tr><tr><td>Test_MAPE</td><td>0.15558</td></tr><tr><td>Test_MSE</td><td>0.46807</td></tr><tr><td>Test_RMSE</td><td>0.68415</td></tr><tr><td>best_epoch</td><td>23</td></tr><tr><td>best_val_loss</td><td>0.00859</td></tr><tr><td>epoch</td><td>33</td></tr><tr><td>loss</td><td>0.02119</td></tr><tr><td>val_loss</td><td>0.00974</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">magic-sweep-50</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ytsyan91" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ytsyan91</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_092325-ytsyan91/logs</code>

# %% [markdown]
# # Transformer

# %%
sweep_config = {
    'name': 'New_Transformer',
    'method': 'bayes', #grid, random
    'metric': {
      'name': 'best_val_loss',
      'goal': 'minimize'   
    },
    'parameters': {
        'batch_size': {
            'values': [128, 64, 32]
        },
        'dropout': {
            'values': [0, 0.1, 0.3]
        },
        'timestep': {
            'distribution': "int_uniform",
            'min': 1,
            'max': 12
        },
        'n_heads': {
            'values': [2, 4, 8]
        },
        'ff_dim': {
            'values': [128,256]
        },
        'n_blocks': {
            'values': [2, 4, 8]
        },
        'embed_dim': {
            'values': [32, 64, 128]
        },
        'time_2_vec': {
            'values': [2,3,4]
        }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, entity="ancy", project="FORTALEZA-2022-06-22-HYBRID")
# Out:
# Create sweep with ID: wcv8226m
# Sweep URL: https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m

# %%
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, feat_dim, num_heads, ff_dim, rate = 0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads = num_heads, key_dim = embed_dim)
        self.ffn = keras.Sequential( [layers.Dense(ff_dim, activation = "gelu"), layers.Dense(feat_dim),] )
        self.layernorm1 = layers.BatchNormalization()
        self.layernorm2 = layers.BatchNormalization()
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)
        self.embed_dim = embed_dim
        self.feat_dim = feat_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.rate = rate

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training = training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training = training)
        return self.layernorm2(out1 + ffn_output)

    def get_config(self):

        config = super().get_config()
        config.update({
            'embed_dim': self.embed_dim,
            'feat_dim': self.feat_dim,
            'num_heads': self.num_heads,
            'ff_dim': self.ff_dim,
            'rate': self.rate,
        })
        return config

# %%
class Time2Vec(keras.layers.Layer):
    def __init__(self, kernel_size = 1):
        super(Time2Vec, self).__init__(trainable = True, name = 'Time2VecLayer')
        self.k = kernel_size

    def build(self, input_shape):
        # trend
        self.wb = self.add_weight(name = 'wb', shape = (input_shape[1],), initializer = 'uniform', trainable = True)
        self.bb = self.add_weight(name = 'bb', shape = (input_shape[1],), initializer = 'uniform', trainable = True)
        # periodic
        self.wa = self.add_weight(name = 'wa', shape = (1, input_shape[1], self.k), initializer = 'uniform', trainable = True)
        self.ba = self.add_weight(name = 'ba', shape = (1, input_shape[1], self.k), initializer = 'uniform', trainable = True)
        super(Time2Vec, self).build(input_shape)

    def call(self, inputs, **kwargs):
        bias = self.wb * inputs + self.bb
        dp = K.dot(inputs, self.wa) + self.ba
        wgts = K.sin(dp) # or K.cos(.)
        ret = K.concatenate([K.expand_dims(bias, -1), wgts], -1)
        ret = K.reshape(ret, (-1, inputs.shape[1] * (self.k + 1)))
        return ret

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1] * (self.k + 1))

    def get_config(self):

        config = super().get_config()
        config.update({
            'kernel_size': self.k,
        })
        return config

# %%
EPOCHS = 50
N_HEADS = 8
N_FOLDS = 10
FF_DIM = 256
N_BLOCKS = 6
EMBED_DIM = 64
BATCH_SIZE = 16
WINDOW_SIZE = 65
DROPUT_RATE = 0.0
TIME_2_VEC_DIM = 3
TRAIN_MODEL = True
SKIP_CONNECTION_STRENGTH = 0.9

# %%
def get_model(input_shape, time2vec_dim = 3):
    inp = Input(input_shape)
    x = inp

    time_embedding = keras.layers.TimeDistributed(Time2Vec(time2vec_dim - 1))(x)
    x = Concatenate(axis = -1)([x, time_embedding])
    x = layers.LayerNormalization(epsilon = 1e-6)(x)

    for k in range(N_BLOCKS):
        x_old = x
        transformer_block = TransformerBlock(EMBED_DIM, input_shape[-1] + ( input_shape[-1] * time2vec_dim), N_HEADS, FF_DIM, DROPUT_RATE)
        x = transformer_block(x)
        x = ((1.0 - SKIP_CONNECTION_STRENGTH) * x) + (SKIP_CONNECTION_STRENGTH * x_old)

    x = layers.Flatten()(x)

    x = layers.Dense(128, activation = "selu")(x)
    x = layers.Dropout(DROPUT_RATE)(x)
    x = Dense(1, activation = 'linear')(x)

    out = x
    model = Model(inp, out)
    return model

# %%
def get_model2():

    config_defaults = {
    'batch_size': 128,
    'lr': 1e-3,
    'timestep': 3,
    'n_heads': 8,
    'ff_dim':256,
    'n_blocks':6,
    'embed_dim':64,
    'dropout':0,
    'time_2_vec':3
    }

    wandb.init(config=config_defaults)
    config = wandb.config
    train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y = make_data3(hourly, config.timestep, resid_check=True, resid=False, univariate=False)


    batch_size=config.batch_size
    lr=config.lr
    N_HEADS = config.n_heads
    FF_DIM = config.ff_dim
    N_BLOCKS = config.n_blocks
    EMBED_DIM = config.embed_dim
    DROPUT_RATE = config.dropout
    time2vec_dim = config.time_2_vec

    input_shape = train_X.shape[1:]
    inp = Input(input_shape)
    x = inp

    time_embedding = keras.layers.TimeDistributed(Time2Vec(time2vec_dim - 1))(x)
    x = Concatenate(axis = -1)([x, time_embedding])
    x = layers.LayerNormalization(epsilon = 1e-6)(x)

    for k in range(N_BLOCKS):
        x_old = x
        transformer_block = TransformerBlock(EMBED_DIM, input_shape[-1] + ( input_shape[-1] * time2vec_dim), N_HEADS, FF_DIM, DROPUT_RATE)
        x = transformer_block(x)
        x = ((1.0 - SKIP_CONNECTION_STRENGTH) * x) + (SKIP_CONNECTION_STRENGTH * x_old)

    x = layers.Flatten()(x)

    x = layers.Dense(128, activation = "selu")(x)
    x = layers.Dropout(DROPUT_RATE)(x)
    x = Dense(1, activation = 'linear')(x)

    out = x
    model = Model(inp, out)

    model.compile(
        loss="mse",
        optimizer=Adam(learning_rate=lr)
                  )

    model.fit(train_X, train_y, batch_size=config.batch_size,
              epochs=200, verbose=0, shuffle=False,
              validation_data=(valid_X, valid_y),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=10, restore_best_weights=True)]
              )
    
    yhat = model.predict(test_X)
    yhat_inv = scaler_y.inverse_transform(yhat)
    resid_sum = (yhat_inv+sarima_pred.values[config.timestep:])
    resid_sum2 = (yhat_inv+sarima_pred2.values[config.timestep:])

    wandb.log({"Test_MSE": mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    wandb.log({"Test_RMSE": sqrt(mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y)))})

    wandb.log({"Test_MAE": mean_absolute_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    wandb.log({"Test_MAPE": mean_absolute_percentage_error(resid_sum2, scaler_y.inverse_transform(test_y))})
    
    return model

# %%
wandb.agent(sweep_id, get_model2, count=50)
# Out:
# wandb: Agent Starting Run: 7y0ltbv7 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 32
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 6
# wandb: Currently logged in as: ancy. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_075947-7y0ltbv7</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/7y0ltbv7" target="_blank">worthy-sweep-1</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# wandb: WARNING The save_model argument by default saves the model in the HDF5 format that cannot save custom objects like subclassed models and custom layers. This behavior will be deprecated in a future release in favor of the SavedModel format. Meanwhile, the HDF5 model is saved as W&B files and the SavedModel as W&B Artifacts.
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.139 MB of 3.139 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▅▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▅▂▃▂▁▂▄▁▁▁▂▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.6365</td></tr><tr><td>Test_MAPE</td><td>0.19411</td></tr><tr><td>Test_MSE</td><td>0.62818</td></tr><tr><td>Test_RMSE</td><td>0.79258</td></tr><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.01276</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>0.06535</td></tr><tr><td>val_loss</td><td>0.01561</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">worthy-sweep-1</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/7y0ltbv7" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/7y0ltbv7</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_075947-7y0ltbv7/logs</code>
# wandb: Agent Starting Run: okiwpaeo with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0
# wandb: 	embed_dim: 32
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 2
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 7
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_080043-okiwpaeo</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/okiwpaeo" target="_blank">radiant-sweep-2</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.189 MB of 2.189 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▅▇▄▄█▁▅▂▂▁▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.99996</td></tr><tr><td>Test_MAPE</td><td>0.26533</td></tr><tr><td>Test_MSE</td><td>1.45936</td></tr><tr><td>Test_RMSE</td><td>1.20804</td></tr><tr><td>best_epoch</td><td>5</td></tr><tr><td>best_val_loss</td><td>0.03535</td></tr><tr><td>epoch</td><td>15</td></tr><tr><td>loss</td><td>0.01648</td></tr><tr><td>val_loss</td><td>0.04191</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">radiant-sweep-2</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/okiwpaeo" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/okiwpaeo</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_080043-okiwpaeo/logs</code>
# wandb: Agent Starting Run: rvoeoka3 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 4
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 2
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_080129-rvoeoka3</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/rvoeoka3" target="_blank">rural-sweep-3</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.502 MB of 3.502 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▁</td></tr><tr><td>val_loss</td><td>▂█▄▂▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.63334</td></tr><tr><td>Test_MAPE</td><td>0.1829</td></tr><tr><td>Test_MSE</td><td>0.63717</td></tr><tr><td>Test_RMSE</td><td>0.79823</td></tr><tr><td>best_epoch</td><td>37</td></tr><tr><td>best_val_loss</td><td>0.01617</td></tr><tr><td>epoch</td><td>47</td></tr><tr><td>loss</td><td>0.02258</td></tr><tr><td>val_loss</td><td>0.01989</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">rural-sweep-3</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/rvoeoka3" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/rvoeoka3</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_080129-rvoeoka3/logs</code>
# wandb: Agent Starting Run: 48rtf3yf with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 5
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_080226-48rtf3yf</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/48rtf3yf" target="_blank">splendid-sweep-4</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.536 MB of 5.536 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▅▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▂▁▁▁▂▃▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.70854</td></tr><tr><td>Test_MAPE</td><td>0.25811</td></tr><tr><td>Test_MSE</td><td>0.82149</td></tr><tr><td>Test_RMSE</td><td>0.90636</td></tr><tr><td>best_epoch</td><td>10</td></tr><tr><td>best_val_loss</td><td>0.01196</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>0.06694</td></tr><tr><td>val_loss</td><td>0.01374</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">splendid-sweep-4</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/48rtf3yf" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/48rtf3yf</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_080226-48rtf3yf/logs</code>
# wandb: Agent Starting Run: h0g82fu8 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 9
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_080329-h0g82fu8</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/h0g82fu8" target="_blank">breezy-sweep-5</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.653 MB of 5.653 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▄▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃█▂▁▁▁▁▂▁▁▂▁▁▂▂▁▁▁▁▁▂▁▁▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.68497</td></tr><tr><td>Test_MAPE</td><td>0.25006</td></tr><tr><td>Test_MSE</td><td>0.7776</td></tr><tr><td>Test_RMSE</td><td>0.88182</td></tr><tr><td>best_epoch</td><td>16</td></tr><tr><td>best_val_loss</td><td>0.01747</td></tr><tr><td>epoch</td><td>26</td></tr><tr><td>loss</td><td>0.0841</td></tr><tr><td>val_loss</td><td>0.05875</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">breezy-sweep-5</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/h0g82fu8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/h0g82fu8</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_080329-h0g82fu8/logs</code>
# wandb: Agent Starting Run: hgiyehf6 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 2
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_080524-hgiyehf6</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/hgiyehf6" target="_blank">cosmic-sweep-6</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.778 MB of 2.778 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▅▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▂▁▂▂▁▁▁▁▁▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.5406</td></tr><tr><td>Test_MAPE</td><td>0.1655</td></tr><tr><td>Test_MSE</td><td>0.47674</td></tr><tr><td>Test_RMSE</td><td>0.69046</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.00902</td></tr><tr><td>epoch</td><td>29</td></tr><tr><td>loss</td><td>0.03823</td></tr><tr><td>val_loss</td><td>0.00966</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">cosmic-sweep-6</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/hgiyehf6" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/hgiyehf6</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_080524-hgiyehf6/logs</code>
# wandb: Agent Starting Run: gffa1umy with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 2
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_080605-gffa1umy</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gffa1umy" target="_blank">visionary-sweep-7</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='9.339 MB of 9.339 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▂▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.56795</td></tr><tr><td>Test_MAPE</td><td>0.17961</td></tr><tr><td>Test_MSE</td><td>0.51213</td></tr><tr><td>Test_RMSE</td><td>0.71563</td></tr><tr><td>best_epoch</td><td>17</td></tr><tr><td>best_val_loss</td><td>0.00921</td></tr><tr><td>epoch</td><td>27</td></tr><tr><td>loss</td><td>0.03995</td></tr><tr><td>val_loss</td><td>0.00955</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">visionary-sweep-7</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gffa1umy" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/gffa1umy</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_080605-gffa1umy/logs</code>
# wandb: Agent Starting Run: bg4fqi0v with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 2
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_080711-bg4fqi0v</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bg4fqi0v" target="_blank">peachy-sweep-8</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.723 MB of 4.723 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▄▄▄▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▃▂▃▃▂▂▁▁▁▁▂▂▁▄▁▄▁▃▁▂▃▁▂▃▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.58049</td></tr><tr><td>Test_MAPE</td><td>0.16027</td></tr><tr><td>Test_MSE</td><td>0.52265</td></tr><tr><td>Test_RMSE</td><td>0.72294</td></tr><tr><td>best_epoch</td><td>16</td></tr><tr><td>best_val_loss</td><td>0.01099</td></tr><tr><td>epoch</td><td>26</td></tr><tr><td>loss</td><td>0.05519</td></tr><tr><td>val_loss</td><td>0.0186</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">peachy-sweep-8</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bg4fqi0v" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/bg4fqi0v</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_080711-bg4fqi0v/logs</code>
# wandb: Agent Starting Run: oyfqynet with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_080757-oyfqynet</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/oyfqynet" target="_blank">jolly-sweep-9</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.454 MB of 4.454 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>loss</td><td>█▅▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53357</td></tr><tr><td>Test_MAPE</td><td>0.15951</td></tr><tr><td>Test_MSE</td><td>0.45909</td></tr><tr><td>Test_RMSE</td><td>0.67756</td></tr><tr><td>best_epoch</td><td>30</td></tr><tr><td>best_val_loss</td><td>0.00865</td></tr><tr><td>epoch</td><td>40</td></tr><tr><td>loss</td><td>0.03469</td></tr><tr><td>val_loss</td><td>0.00867</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">jolly-sweep-9</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/oyfqynet" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/oyfqynet</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_080757-oyfqynet/logs</code>
# wandb: Agent Starting Run: a854kgbp with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_080848-a854kgbp</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/a854kgbp" target="_blank">generous-sweep-10</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.649 MB of 3.649 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>██▅▅▄▄▃▃▃▂▂▂▂▁▂▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃██▁▂▁▁▁▁▁▂▁▁▁▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.52964</td></tr><tr><td>Test_MAPE</td><td>0.15676</td></tr><tr><td>Test_MSE</td><td>0.45513</td></tr><tr><td>Test_RMSE</td><td>0.67463</td></tr><tr><td>best_epoch</td><td>9</td></tr><tr><td>best_val_loss</td><td>0.00853</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.04747</td></tr><tr><td>val_loss</td><td>0.00921</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">generous-sweep-10</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/a854kgbp" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/a854kgbp</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_080848-a854kgbp/logs</code>
# wandb: Agent Starting Run: uwrwuum8 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_080923-uwrwuum8</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/uwrwuum8" target="_blank">atomic-sweep-11</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.231 MB of 1.231 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>loss</td><td>█▅▄▄▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▅▄▂▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53561</td></tr><tr><td>Test_MAPE</td><td>0.15506</td></tr><tr><td>Test_MSE</td><td>0.45964</td></tr><tr><td>Test_RMSE</td><td>0.67796</td></tr><tr><td>best_epoch</td><td>35</td></tr><tr><td>best_val_loss</td><td>0.0086</td></tr><tr><td>epoch</td><td>45</td></tr><tr><td>loss</td><td>0.03236</td></tr><tr><td>val_loss</td><td>0.0088</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">atomic-sweep-11</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/uwrwuum8" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/uwrwuum8</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_080923-uwrwuum8/logs</code>
# wandb: Agent Starting Run: 7b0kb9vw with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_081009-7b0kb9vw</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/7b0kb9vw" target="_blank">jumping-sweep-12</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.829 MB of 8.829 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▃▃▂▃▂▂▂▂▂▂▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▄▅▅▅▃▇▂▃▂▂▂▂▂▁▂▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53365</td></tr><tr><td>Test_MAPE</td><td>0.14943</td></tr><tr><td>Test_MSE</td><td>0.4422</td></tr><tr><td>Test_RMSE</td><td>0.66498</td></tr><tr><td>best_epoch</td><td>34</td></tr><tr><td>best_val_loss</td><td>0.00928</td></tr><tr><td>epoch</td><td>44</td></tr><tr><td>loss</td><td>0.03463</td></tr><tr><td>val_loss</td><td>0.00938</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">jumping-sweep-12</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/7b0kb9vw" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/7b0kb9vw</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_081009-7b0kb9vw/logs</code>
# wandb: Agent Starting Run: flgxhot9 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_081110-flgxhot9</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/flgxhot9" target="_blank">wobbly-sweep-13</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.845 MB of 2.845 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▅▄▄▄▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄▁█▅▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54249</td></tr><tr><td>Test_MAPE</td><td>0.14708</td></tr><tr><td>Test_MSE</td><td>0.44828</td></tr><tr><td>Test_RMSE</td><td>0.66954</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.00954</td></tr><tr><td>epoch</td><td>29</td></tr><tr><td>loss</td><td>0.05631</td></tr><tr><td>val_loss</td><td>0.01164</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">wobbly-sweep-13</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/flgxhot9" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/flgxhot9</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_081110-flgxhot9/logs</code>
# wandb: Agent Starting Run: ydatqek4 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 32
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_081151-ydatqek4</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ydatqek4" target="_blank">ancient-sweep-14</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▅▄▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▇▃█▄▃▁▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.55617</td></tr><tr><td>Test_MAPE</td><td>0.16994</td></tr><tr><td>Test_MSE</td><td>0.50296</td></tr><tr><td>Test_RMSE</td><td>0.7092</td></tr><tr><td>best_epoch</td><td>21</td></tr><tr><td>best_val_loss</td><td>0.00907</td></tr><tr><td>epoch</td><td>31</td></tr><tr><td>loss</td><td>0.03639</td></tr><tr><td>val_loss</td><td>0.00939</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ancient-sweep-14</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ydatqek4" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ydatqek4</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_081151-ydatqek4/logs</code>
# wandb: Agent Starting Run: 563mym44 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 2
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 3
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_081227-563mym44</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/563mym44" target="_blank">misunderstood-sweep-15</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.895 MB of 0.895 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▆▆▅▄▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃▂▂█▅▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54652</td></tr><tr><td>Test_MAPE</td><td>0.16456</td></tr><tr><td>Test_MSE</td><td>0.48962</td></tr><tr><td>Test_RMSE</td><td>0.69973</td></tr><tr><td>best_epoch</td><td>24</td></tr><tr><td>best_val_loss</td><td>0.00899</td></tr><tr><td>epoch</td><td>34</td></tr><tr><td>loss</td><td>0.03373</td></tr><tr><td>val_loss</td><td>0.00902</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">misunderstood-sweep-15</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/563mym44" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/563mym44</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_081227-563mym44/logs</code>
# wandb: Agent Starting Run: feh1n9tc with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 32
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 2
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_081303-feh1n9tc</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/feh1n9tc" target="_blank">efficient-sweep-16</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.560 MB of 0.560 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▁▂▁▁▃▂▁▂▃▁▁▃▂▁▁▁▁▁▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53302</td></tr><tr><td>Test_MAPE</td><td>0.14947</td></tr><tr><td>Test_MSE</td><td>0.44331</td></tr><tr><td>Test_RMSE</td><td>0.66582</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.00879</td></tr><tr><td>epoch</td><td>29</td></tr><tr><td>loss</td><td>0.05332</td></tr><tr><td>val_loss</td><td>0.01273</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">efficient-sweep-16</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/feh1n9tc" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/feh1n9tc</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_081303-feh1n9tc/logs</code>
# wandb: Agent Starting Run: 1th11q5n with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 2
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_081334-1th11q5n</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/1th11q5n" target="_blank">ethereal-sweep-17</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.457 MB of 1.457 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▇▆▆▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂█▁▃▂▂▂▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.56373</td></tr><tr><td>Test_MAPE</td><td>0.17883</td></tr><tr><td>Test_MSE</td><td>0.52321</td></tr><tr><td>Test_RMSE</td><td>0.72334</td></tr><tr><td>best_epoch</td><td>24</td></tr><tr><td>best_val_loss</td><td>0.00914</td></tr><tr><td>epoch</td><td>34</td></tr><tr><td>loss</td><td>0.03671</td></tr><tr><td>val_loss</td><td>0.01522</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ethereal-sweep-17</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/1th11q5n" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/1th11q5n</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_081334-1th11q5n/logs</code>
# wandb: Agent Starting Run: 131i33jc with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_081404-131i33jc</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/131i33jc" target="_blank">fanciful-sweep-18</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.649 MB of 3.649 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# ...
# wandb: 	n_blocks: 2
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083003-w1sghiax</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/w1sghiax" target="_blank">earnest-sweep-45</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.077 MB of 1.077 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>loss</td><td>█▂▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁█▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.56591</td></tr><tr><td>Test_MAPE</td><td>0.15424</td></tr><tr><td>Test_MSE</td><td>0.51855</td></tr><tr><td>Test_RMSE</td><td>0.72011</td></tr><tr><td>best_epoch</td><td>35</td></tr><tr><td>best_val_loss</td><td>0.01142</td></tr><tr><td>epoch</td><td>45</td></tr><tr><td>loss</td><td>0.02048</td></tr><tr><td>val_loss</td><td>0.0129</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">earnest-sweep-45</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/w1sghiax" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/w1sghiax</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083003-w1sghiax/logs</code>
# wandb: Agent Starting Run: azzphzcm with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 2
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083034-azzphzcm</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/azzphzcm" target="_blank">sparkling-sweep-46</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.324 MB of 0.324 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▇▆▅▄▃▃▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.53143</td></tr><tr><td>Test_MAPE</td><td>0.1529</td></tr><tr><td>Test_MSE</td><td>0.45166</td></tr><tr><td>Test_RMSE</td><td>0.67206</td></tr><tr><td>best_epoch</td><td>23</td></tr><tr><td>best_val_loss</td><td>0.00877</td></tr><tr><td>epoch</td><td>33</td></tr><tr><td>loss</td><td>0.03185</td></tr><tr><td>val_loss</td><td>0.00906</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sparkling-sweep-46</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/azzphzcm" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/azzphzcm</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083034-azzphzcm/logs</code>
# wandb: Agent Starting Run: jcsfueq7 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 32
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 2
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083110-jcsfueq7</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/jcsfueq7" target="_blank">eager-sweep-47</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.684 MB of 0.684 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▇▅▅▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃█▅▃▇▅▂▃▂▁▃▂▁▂▁▂▁▁▁▁▁▁▁▁▂▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54341</td></tr><tr><td>Test_MAPE</td><td>0.16281</td></tr><tr><td>Test_MSE</td><td>0.47582</td></tr><tr><td>Test_RMSE</td><td>0.6898</td></tr><tr><td>best_epoch</td><td>29</td></tr><tr><td>best_val_loss</td><td>0.00895</td></tr><tr><td>epoch</td><td>39</td></tr><tr><td>loss</td><td>0.03601</td></tr><tr><td>val_loss</td><td>0.00904</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">eager-sweep-47</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/jcsfueq7" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/jcsfueq7</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083110-jcsfueq7/logs</code>
# wandb: Agent Starting Run: ook0wr8r with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 2
# wandb: 	n_heads: 4
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083146-ook0wr8r</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ook0wr8r" target="_blank">sweepy-sweep-48</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.933 MB of 0.933 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▄▄▃▃▃▃▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.52503</td></tr><tr><td>Test_MAPE</td><td>0.15656</td></tr><tr><td>Test_MSE</td><td>0.44845</td></tr><tr><td>Test_RMSE</td><td>0.66966</td></tr><tr><td>best_epoch</td><td>17</td></tr><tr><td>best_val_loss</td><td>0.00854</td></tr><tr><td>epoch</td><td>27</td></tr><tr><td>loss</td><td>0.03801</td></tr><tr><td>val_loss</td><td>0.00881</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sweepy-sweep-48</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ook0wr8r" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/ook0wr8r</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083146-ook0wr8r/logs</code>
# wandb: Agent Starting Run: 46zzwe4y with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 2
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083222-46zzwe4y</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/46zzwe4y" target="_blank">breezy-sweep-49</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.297 MB of 0.297 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▅█▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54231</td></tr><tr><td>Test_MAPE</td><td>0.15624</td></tr><tr><td>Test_MSE</td><td>0.46878</td></tr><tr><td>Test_RMSE</td><td>0.68468</td></tr><tr><td>best_epoch</td><td>102</td></tr><tr><td>best_val_loss</td><td>0.00904</td></tr><tr><td>epoch</td><td>112</td></tr><tr><td>loss</td><td>0.02139</td></tr><tr><td>val_loss</td><td>0.00911</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">breezy-sweep-49</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/46zzwe4y" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/46zzwe4y</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083222-46zzwe4y/logs</code>
# wandb: Agent Starting Run: lxysqez1 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0
# wandb: 	embed_dim: 32
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 2
# wandb: 	n_heads: 8
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 1
# Tracking run with wandb version 0.12.19
# Run data is saved locally in <code>/content/wandb/run-20220627_083303-lxysqez1</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/lxysqez1" target="_blank">deep-sweep-50</a></strong> to <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/sweeps/wcv8226m</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.100 MB of 0.100 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>▁</td></tr><tr><td>Test_MAPE</td><td>▁</td></tr><tr><td>Test_MSE</td><td>▁</td></tr><tr><td>Test_RMSE</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▃▂▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_MAE</td><td>0.54883</td></tr><tr><td>Test_MAPE</td><td>0.14965</td></tr><tr><td>Test_MSE</td><td>0.46384</td></tr><tr><td>Test_RMSE</td><td>0.68106</td></tr><tr><td>best_epoch</td><td>90</td></tr><tr><td>best_val_loss</td><td>0.0103</td></tr><tr><td>epoch</td><td>100</td></tr><tr><td>loss</td><td>0.02168</td></tr><tr><td>val_loss</td><td>0.01061</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">deep-sweep-50</strong>: <a href="https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/lxysqez1" target="_blank">https://wandb.ai/ancy/FORTALEZA-2022-06-22-HYBRID/runs/lxysqez1</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220627_083303-lxysqez1/logs</code>

# %% [markdown]
# # Transformer 2

# %%
from tensorflow.keras import layers

# %%
sweep_config = {
    'name': 'Transformer',
    'method': 'bayes', #grid, random
    'metric': {
      'name': 'best_val_loss',
      'goal': 'minimize'   
    },
    'parameters': {
        'batch_size': {
            'values': [256, 128, 64, 32]
        },
        'dropout': {
            'values': [0.1, 0.3, 0.5]
        },
        'units': {
            'values': [64, 128, 256]
        },
        'timestep': {
            'distribution': "int_uniform",
            'min': 1,
            'max': 12
        },
        'head_size': {
            'values': [256, 128, 512]
        },
        'num_heads': {
            'values': [4, 8, 2]
        },
        'ff_dim': {
            'values': [4]
        },
        'num_blocks': {
            'values': [2, 4, 8]
        },
        'lr': {
            'values': [1e-1, 1e-2, 1e-3]
        }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, entity="ancy", project="Recifehora_oldtrans")
# Out:
# Create sweep with ID: muajowvf
# Sweep URL: https://wandb.ai/ancy/Recifehora_oldtrans/sweeps/muajowvf

# %%
def transformer_encoder(inputs, head_size=256, num_heads=4, ff_dim=4, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
def build_model():

    config_defaults = {
    'batch_size': 128,
    'lr': 1e-3,
    'units': 64,
    'timestep': 3,
    'dropout': 0.3,
    'head_size': 256,
    'num_heads': 4,
    'ff_dim': 4,
    'num_blocks': 4
    }
    wandb.init(config=config_defaults)
    config = wandb.config
    train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y = make_data3(hourly, config.timestep, resid_check=True, resid=False, univariate=False)


    num_transformer_blocks=config.num_blocks
    inputs = keras.Input(shape=train_X.shape[1:])
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size=config.head_size, num_heads=config.num_heads, ff_dim=config.ff_dim, dropout=config.dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    x = layers.Dense(config.units, activation="relu")(x)
    x = layers.Dropout(config.dropout)(x)
    outputs = layers.Dense(1)(x)

    lr = config.lr

    model = keras.Model(inputs, outputs)
    model.compile(
        loss="mse",
        optimizer=Adam(learning_rate=lr)
    )

    model.fit(train_X, train_y, batch_size=config.batch_size,
              epochs=200, verbose=0, shuffle=False,
              validation_data=(valid_X, valid_y),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=10, restore_best_weights=True), ReduceLROnPlateau(monitor='val_loss',patience=5, min_lr=1e-6)])
    
      
    yhat = model.predict(test_X)
    yhat_inv = scaler_y.inverse_transform(yhat)
    resid_sum = (yhat_inv+sarima_pred.values[config.timestep:])

    print(sqrt(mean_squared_error(resid_sum, scaler_y.inverse_transform(test_y))))
    print(mean_absolute_error(resid_sum, scaler_y.inverse_transform(test_y)))
    print(mean_absolute_percentage_error(resid_sum, scaler_y.inverse_transform(test_y)))

    
    return keras.Model(inputs, outputs)

# %%
wandb.agent(sweep_id, build_model, count=50)
