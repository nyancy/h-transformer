# %% [markdown]
# # Imports and Colab Mount

# %%
import datetime
import seaborn as sn
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats as stats
import glob
from math import sqrt

from sklearn.preprocessing import StandardScaler, MinMaxScaler

import keras
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, LSTM, LeakyReLU, Dropout, GRU, SimpleRNN, Input, LSTM, Dense, Bidirectional, Concatenate, Reshape, Lambda, Bidirectional
from keras.models import Model, Sequential
from keras import backend as K
from tensorflow.keras import layers
from keras.callbacks import Callback, ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
import seaborn as sns

from numpy.random import seed
#from tensorflow import set_random_seed

# %matplotlib inline

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load Data

# %%
hourly = pd.read_excel("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/BASERECIFEhorario.xlsx", index_col=0, parse_dates=[["Data", "HORA (UTC)"]])
hourly = hourly[ ['Velocidade'] + [ col for col in hourly.columns if col != 'Velocidade' ] ]
quarto = int(hourly["Velocidade"].shape[0]/4)

resid_train = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/recifehora_resid_train.csv").drop("Unnamed: 0", axis=1)
resid_test = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/recifehora_resid_test2.csv").drop("Unnamed: 0", axis=1)

sarima_pred = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/recifehora_prediction.csv").drop("Unnamed: 0", axis=1)
sarima_pred2 = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/recifehora_prediction2.csv").drop("Unnamed: 0", axis=1)

#hourly["Velocidade"] = pd.concat([resid_train, resid_test]).reset_index()["0"].values
resid_series = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/recifehora_resid_series.csv").drop("Unnamed: 0", axis=1)

train_h = hourly.iloc[:quarto*2]
valid_h = hourly.iloc[quarto*2:quarto*3]
test_h = hourly.iloc[quarto*3:]

# %%
hourly = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/alternative.csv", index_col=0, parse_dates=True)
#hourly = hourly[ ['Velocidade'] + [ col for col in hourly.columns if col != 'Velocidade' ] ]
quarto = int(hourly["DC_POWER"].shape[0]/4)

#resid_train = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/natalhora_resid_train.csv").drop("Unnamed: 0", axis=1)
#resid_test = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/natalhora_resid_test2.csv").drop("Unnamed: 0", axis=1)

sarima_pred = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/alternative_prediction_bad.csv").drop("Unnamed: 0", axis=1)
sarima_pred2 = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/alternative_prediction_good.csv").drop("Unnamed: 0", axis=1)

#hourly["Velocidade"] = pd.concat([resid_train, resid_test]).reset_index()["0"].values
resid_series = pd.read_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/alternative_resid_series.csv").drop("Unnamed: 0", axis=1)

train_h = hourly.iloc[:quarto*2]
valid_h = hourly.iloc[quarto*2:quarto*3]
test_h = hourly.iloc[quarto*3:]

# %%
test_h["DC_POWER"].mean()
# Out:
# 5183.7313246444855

# %%
resid_series.shape
#372
# Out:
# (744, 1)

# %%
train_h['Velocidade'].to_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/recifevelocidade_train.csv")
resid_series['0'][:372].to_csv("/content/drive/MyDrive/Hybrid Transformer/Datasets/Vento/reciferesid_train.csv")

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
	n_vars = 1 if type(data) is list else data.shape[1]
	df = pd.DataFrame(data)
	cols, names = list(), list()
	# input sequence (t-n, ... t-1)
	for i in range(n_in, 0, -1):
		cols.append(df.shift(i))
		names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
	# forecast sequence (t, t+1, ... t+n)
	for i in range(0, n_out):
		cols.append(df.shift(-i))
		if i == 0:
			names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
		else:
			names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
	# put it all together
	agg = pd.concat(cols, axis=1)
	agg.columns = names
	# drop rows with NaN values
	if dropnan:
		agg.dropna(inplace=True)
	return agg

# %%
def make_data(data, timestep, resid_check=False):
  values = data.values
  values = values.astype('float32')
  #scaler = MinMaxScaler(feature_range=(0, 1))
  #scaled = scaler.fit_transform(values)
  
  timestep = timestep
  n_features = data.shape[1]
  n_obs = timestep * n_features
  reframed = series_to_supervised(values, timestep, 1)
  reframed = reframed.iloc[: , :1-n_features]

  values = reframed.values
  indice1 = train_h.shape[0]
  indice2 = valid_h.shape[0]

  train = values[:indice1, :]
  valid = values[indice1:indice1+indice2, :]
  test = values[indice1+indice2:, :]

  train_X, train_y = train[:, :-1], train[:, -1]
  valid_X, valid_y = valid[:, :-1], valid[:, -1]
  test_X, test_y = test[:, :-1], test[:, -1]

  if (resid_check==True):
    train_y = resid_train.values[:quarto*2]
    valid_y = resid_train.values[quarto*2:]

  scaler = MinMaxScaler(feature_range=(0, 1)).fit(train_X)
  train_X = scaler.transform(train_X)
  valid_X = scaler.transform(valid_X)
  test_X = scaler.transform(test_X)

  scaler_y = MinMaxScaler(feature_range=(0, 1)).fit(train_y.reshape(-1,1))
  train_y = scaler_y.transform(train_y.reshape(-1,1))
  valid_y = scaler_y.transform(valid_y.reshape(-1,1))
  test_y = scaler_y.transform(test_y.reshape(-1,1))

  train_X = train_X.reshape((train_X.shape[0], timestep, n_features))
  valid_X = valid_X.reshape((valid_X.shape[0], timestep, n_features))
  test_X = test_X.reshape((test_X.shape[0], timestep, n_features))
  return train_X, train_y, valid_X, valid_y, test_X, test_y

# %%
def make_data2(data, timestep, resid_check=False):
  values = data.values
  values = values.astype('float32')
  #scaler = MinMaxScaler(feature_range=(0, 1))
  #scaled = scaler.fit_transform(values)
  
  timestep = timestep
  n_features = data.shape[1]
  n_obs = timestep * n_features
  reframed = series_to_supervised(values, timestep, 1)
  reframed = reframed.iloc[: , :1-n_features]

  values = reframed.values
  indice1 = train_h.shape[0]
  indice2 = valid_h.shape[0]

  train = values[:indice1, :]
  valid = values[indice1:indice1+indice2, :]
  test = values[indice1+indice2:, :]

  train_X, train_y = train[:, :-1], train[:, -1]
  valid_X, valid_y = valid[:, :-1], valid[:, -1]
  test_X, test_y = test[:, :-1], test[:, -1]

  if (resid_check==True):
    train_y = resid_train.values[:quarto*2]
    valid_y = resid_train.values[quarto*2:]

  scaler = MinMaxScaler(feature_range=(0, 1)).fit(train_X)
  train_X = scaler.transform(train_X)
  valid_X = scaler.transform(valid_X)
  test_X = scaler.transform(test_X)

  scaler_y = MinMaxScaler(feature_range=(0, 1)).fit(train_y.reshape(-1,1))
  train_y = scaler_y.transform(train_y.reshape(-1,1))
  valid_y = scaler_y.transform(valid_y.reshape(-1,1))
  test_y = scaler_y.transform(test_y.reshape(-1,1))

  train_X = train_X.reshape((train_X.shape[0], timestep, n_features))
  valid_X = valid_X.reshape((valid_X.shape[0], timestep, n_features))
  test_X = test_X.reshape((test_X.shape[0], timestep, n_features))
  return train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y

# %%
def make_data3(df, timestep, resid_check=False, resid=False, univariate=False):

  data = df.copy()

  if resid==True:
    data['Velocidade'] = resid_series.values

  if univariate==True:
    values = data["Velocidade"].values
    values = values.astype('float32')
    values = values.reshape(-1, 1)

    timestep = timestep
    n_features = 1
    n_obs = timestep * n_features
    reframed = series_to_supervised(values, timestep, 1)

  else:
    values = data.values
    values = values.astype('float32')
    #scaler = MinMaxScaler(feature_range=(0, 1))
    #scaled = scaler.fit_transform(values)
    
    timestep = timestep
    n_features = data.shape[1]
    n_obs = timestep * n_features
    reframed = series_to_supervised(values, timestep, 1)
    reframed = reframed.iloc[: , :1-n_features]

  values = reframed.values
  indice1 = train_h.shape[0]
  indice2 = valid_h.shape[0]

  train = values[:indice1, :]
  valid = values[indice1:indice1+indice2, :]
  test = values[indice1+indice2:, :]

  train_X, train_y = train[:, :-1], train[:, -1]
  valid_X, valid_y = valid[:, :-1], valid[:, -1]
  test_X, test_y = test[:, :-1], test[:, -1]

  if (resid_check==True):
    train_y = resid_series.values[timestep:(quarto*2)+timestep]
    valid_y = resid_series.values[(quarto*2)+timestep:(quarto*3)+timestep]
    #test_y = resid_series.values[(quarto*3)+timestep:]
  if (resid==True):
    test_y = df['Velocidade'].values[(quarto*3)+timestep:]

  scaler = MinMaxScaler(feature_range=(0, 1)).fit(train_X)
  train_X = scaler.transform(train_X)
  valid_X = scaler.transform(valid_X)
  test_X = scaler.transform(test_X)

  scaler_y = MinMaxScaler(feature_range=(0, 1)).fit(train_y.reshape(-1,1))
  train_y = scaler_y.transform(train_y.reshape(-1,1))
  valid_y = scaler_y.transform(valid_y.reshape(-1,1))
  test_y = scaler_y.transform(test_y.reshape(-1,1))

  train_X = train_X.reshape((train_X.shape[0], timestep, n_features))
  valid_X = valid_X.reshape((valid_X.shape[0], timestep, n_features))
  test_X = test_X.reshape((test_X.shape[0], timestep, n_features))
  return train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y

# %% [markdown]
# # WanDB

# %%
# !pip install wandb -qq
import wandb
from wandb.keras import WandbCallback
# !wandb login
# Out:
#      |████████████████████████████████| 1.8 MB 5.1 MB/s
#      |████████████████████████████████| 144 kB 58.5 MB/s
#      |████████████████████████████████| 181 kB 64.8 MB/s
#      |████████████████████████████████| 63 kB 1.8 MB/s
#   Building wheel for pathtools (setup.py) ... done
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %% [markdown]
# # Train

# %% [markdown]
# # RNN

# %%
# Configure the sweep – specify the parameters to search through, the search strategy, the optimization metric et all.
sweep_config = {
    'name': 'RNN',
    'method': 'bayes', #grid, random
    'metric': {
      'name': 'best_val_loss',
      'goal': 'minimize'   
    },
    'parameters': {
        'batch_size': {
            'values': [256, 128, 64, 32]
        },
        'dropout': {
            'values': [0, 0.1, 0.3]
        },
        'units': {
            'values': [64, 128, 256]
        },
        'timestep': {
            'distribution': "int_uniform",
            'min': 1,
            'max': 12
        },
        'lr': {
            'values': [1e-2, 1e-1]
        },
        'layers': {
            'values': [1, 2, 4, 8]
        },
        
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, entity="ancy", project="recifehora_RESIDUAL_RNN")
# Out:
# Create sweep with ID: 48p0nggc
# Sweep URL: https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc

# %%
def create_rnn():
    config_defaults = {
    'batch_size': 128,
    'lr': 1e-3,
    'units': 64,
    'timestep': 3,
    'dropout': 0.3,
    'layers': 1,
    }

    wandb.init(config=config_defaults)
    config = wandb.config

    batch_size = config.batch_size
    lr         = config.lr
    num_units  = config.units
    timestep   = config.timestep
    dropout    = config.dropout
    layers     = config.layers

    train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y = make_data2(hourly, timestep, resid_check=True)
    model = Sequential()

    if layers > 1:
      model.add(SimpleRNN(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout, return_sequences=True))

      for i in range(layers-2):
        model.add(SimpleRNN(units = num_units, dropout=dropout, return_sequences=True))

      model.add(SimpleRNN(units = num_units, dropout=dropout))

    else:
      model.add(SimpleRNN(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout))

    model.add(Dense(units = 1))

    model.compile(
        loss="mse",
        optimizer=Adam(learning_rate=lr)
    )

    model.fit(train_X, train_y, batch_size=batch_size,
              epochs=200, verbose=0, shuffle=False,
              validation_data=(valid_X, valid_y),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=10, restore_best_weights=True)])
    
    yhat = model.predict(test_X)
    yhat_inv = scaler_y.inverse_transform(yhat)
    resid_sum = (yhat_inv+sarima_pred.values[timestep:])

    print(sqrt(mean_squared_error(resid_sum, scaler_y.inverse_transform(test_y))))
    print(mean_absolute_error(resid_sum, scaler_y.inverse_transform(test_y)))
    print(mean_absolute_percentage_error(resid_sum, scaler_y.inverse_transform(test_y)))

    return model

# %%
wandb.agent(sweep_id, create_rnn, count=50)
# Out:
# wandb: Agent Starting Run: u5lmwjjq with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 6
# wandb: 	units: 64
# wandb: Currently logged in as: ancy (use `wandb login --relogin` to force relogin)
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051425-u5lmwjjq</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/u5lmwjjq" target="_blank">stellar-sweep-1</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.7907551960942997
# 0.6411053073382728
# 0.22587488506550166
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.189 MB of 0.189 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▂█▇▄▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>40</td></tr><tr><td>best_val_loss</td><td>0.00699</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>loss</td><td>0.0189</td></tr><tr><td>val_loss</td><td>0.007</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">stellar-sweep-1</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/u5lmwjjq" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/u5lmwjjq</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051425-u5lmwjjq/logs</code>
# wandb: Agent Starting Run: 7mwfqbsh with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 2
# wandb: 	units: 64
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051450-7mwfqbsh</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/7mwfqbsh" target="_blank">cerulean-sweep-2</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.7547355955545079
# 0.6172979137811836
# 0.2743235734992043
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.189 MB of 0.189 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▄▅▂▃▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄█▁▄▃▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>14</td></tr><tr><td>best_val_loss</td><td>0.00648</td></tr><tr><td>epoch</td><td>24</td></tr><tr><td>loss</td><td>0.02431</td></tr><tr><td>val_loss</td><td>0.01092</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">cerulean-sweep-2</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/7mwfqbsh" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/7mwfqbsh</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051450-7mwfqbsh/logs</code>
# wandb: Agent Starting Run: yaxeuux2 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	timestep: 12
# wandb: 	units: 64
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051516-yaxeuux2</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/yaxeuux2" target="_blank">trim-sweep-3</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8022783488693976
# 0.6478238389272548
# 0.24018907140247756
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.081 MB of 0.081 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>24</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>34</td></tr><tr><td>loss</td><td>0.01994</td></tr><tr><td>val_loss</td><td>0.00745</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">trim-sweep-3</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/yaxeuux2" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/yaxeuux2</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051516-yaxeuux2/logs</code>
# wandb: Agent Starting Run: jq9k4h8d with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 4
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051542-jq9k4h8d</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/jq9k4h8d" target="_blank">rural-sweep-4</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8508075641080493
# 0.7082603701576572
# 0.24935457973316488
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.011 MB of 0.011 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>loss</td><td>▁█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>30</td></tr><tr><td>best_val_loss</td><td>0.00682</td></tr><tr><td>epoch</td><td>40</td></tr><tr><td>loss</td><td>0.01805</td></tr><tr><td>val_loss</td><td>0.00696</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">rural-sweep-4</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/jq9k4h8d" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/jq9k4h8d</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051542-jq9k4h8d/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: m3yju2c3 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 1
# wandb: 	lr: 0.1
# wandb: 	timestep: 5
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051623-m3yju2c3</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/m3yju2c3" target="_blank">restful-sweep-5</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 1.8969260952790687
# 1.732142582209583
# 0.3783612156063789
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.225 MB of 0.225 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▂▃▃▄▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>▄█▂▅▁▃▁▂▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▅▁▂▁▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.04884</td></tr><tr><td>epoch</td><td>13</td></tr><tr><td>loss</td><td>0.68818</td></tr><tr><td>val_loss</td><td>1.99058</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">restful-sweep-5</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/m3yju2c3" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/m3yju2c3</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051623-m3yju2c3/logs</code>
# wandb: Agent Starting Run: 65wqzjp7 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	timestep: 1
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051644-65wqzjp7</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/65wqzjp7" target="_blank">cosmic-sweep-6</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 2.523523717444115
# 2.3989095765468114
# 0.45644759095238735
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>loss</td><td>▂█▃▂▃▁▂▁▂▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▁▃▁▂▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.09646</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>loss</td><td>4.85721</td></tr><tr><td>val_loss</td><td>2.45367</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">cosmic-sweep-6</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/65wqzjp7" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/65wqzjp7</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051644-65wqzjp7/logs</code>
# wandb: Agent Starting Run: pm7z2yth with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 7
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051710-pm7z2yth</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/pm7z2yth" target="_blank">apricot-sweep-7</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8100919513504303
# 0.6595848721254625
# 0.23098455272929144
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▂█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>23</td></tr><tr><td>best_val_loss</td><td>0.00719</td></tr><tr><td>epoch</td><td>33</td></tr><tr><td>loss</td><td>0.01995</td></tr><tr><td>val_loss</td><td>0.00746</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">apricot-sweep-7</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/pm7z2yth" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/pm7z2yth</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051710-pm7z2yth/logs</code>
# wandb: Agent Starting Run: derrtuun with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 6
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051746-derrtuun</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/derrtuun" target="_blank">fluent-sweep-8</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8069170667438645
# 0.6559580976596839
# 0.22988740985782868
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>17</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>27</td></tr><tr><td>loss</td><td>0.02069</td></tr><tr><td>val_loss</td><td>0.00757</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fluent-sweep-8</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/derrtuun" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/derrtuun</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051746-derrtuun/logs</code>
# wandb: Agent Starting Run: lawfmouq with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 8
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051822-lawfmouq</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/lawfmouq" target="_blank">northern-sweep-9</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8183896833500688
# 0.6679992156438895
# 0.231672014680238
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.390 MB of 1.390 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>10</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>0.0215</td></tr><tr><td>val_loss</td><td>0.00792</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">northern-sweep-9</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/lawfmouq" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/lawfmouq</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051822-lawfmouq/logs</code>
# wandb: Agent Starting Run: rkr7qe5x with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 5
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051852-rkr7qe5x</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/rkr7qe5x" target="_blank">confused-sweep-10</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8128954564082563
# 0.6608827886533829
# 0.2285616788590978
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>9</td></tr><tr><td>best_val_loss</td><td>0.0072</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.02126</td></tr><tr><td>val_loss</td><td>0.00903</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">confused-sweep-10</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/rkr7qe5x" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/rkr7qe5x</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051852-rkr7qe5x/logs</code>
# wandb: Agent Starting Run: vgfn0p76 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 6
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051918-vgfn0p76</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/vgfn0p76" target="_blank">pleasant-sweep-11</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8116977744859881
# 0.6604713489233323
# 0.22951771764680096
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▇▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▇█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>0.02009</td></tr><tr><td>val_loss</td><td>0.00788</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">pleasant-sweep-11</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/vgfn0p76" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/vgfn0p76</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051918-vgfn0p76/logs</code>
# wandb: Agent Starting Run: qulxkhkx with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 7
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_051943-qulxkhkx</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/qulxkhkx" target="_blank">smooth-sweep-12</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8206602020436434
# 0.6695292475244867
# 0.23063182355144587
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>▃█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>17</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>27</td></tr><tr><td>loss</td><td>0.02171</td></tr><tr><td>val_loss</td><td>0.00773</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">smooth-sweep-12</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/qulxkhkx" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/qulxkhkx</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_051943-qulxkhkx/logs</code>
# wandb: Agent Starting Run: 0sg5i96j with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 5
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_052029-0sg5i96j</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/0sg5i96j" target="_blank">snowy-sweep-13</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 1.330004635247981
# 1.1000013079630375
# 0.28292370292504687
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▂▃▃▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>▄█▂▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.03146</td></tr><tr><td>epoch</td><td>12</td></tr><tr><td>loss</td><td>0.38184</td></tr><tr><td>val_loss</td><td>0.16666</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">snowy-sweep-13</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/0sg5i96j" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/0sg5i96j</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_052029-0sg5i96j/logs</code>
# wandb: Agent Starting Run: xdi0mg7a with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 10
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_052054-xdi0mg7a</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/xdi0mg7a" target="_blank">chocolate-sweep-14</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8229575700043694
# 0.6728643237463018
# 0.2358450066013332
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>8</td></tr><tr><td>best_val_loss</td><td>0.00689</td></tr><tr><td>epoch</td><td>18</td></tr><tr><td>loss</td><td>0.01845</td></tr><tr><td>val_loss</td><td>0.00723</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">chocolate-sweep-14</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/xdi0mg7a" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/xdi0mg7a</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_052054-xdi0mg7a/logs</code>
# wandb: Agent Starting Run: vudbq7qg with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 8
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_052125-vudbq7qg</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/vudbq7qg" target="_blank">pleasant-sweep-15</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8153543785583222
# 0.6652040893762237
# 0.2317689321271711
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>14</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>24</td></tr><tr><td>loss</td><td>0.02183</td></tr><tr><td>val_loss</td><td>0.00729</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">pleasant-sweep-15</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/vudbq7qg" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/vudbq7qg</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_052125-vudbq7qg/logs</code>
# wandb: Agent Starting Run: dydecama with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 8
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_052201-dydecama</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/dydecama" target="_blank">warm-sweep-16</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.9145430749170711
# 0.7040580447030784
# 0.25896927992128077
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>22</td></tr><tr><td>best_val_loss</td><td>0.007</td></tr><tr><td>epoch</td><td>32</td></tr><tr><td>loss</td><td>0.01966</td></tr><tr><td>val_loss</td><td>0.00725</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">warm-sweep-16</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/dydecama" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/dydecama</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_052201-dydecama/logs</code>
# wandb: Agent Starting Run: txhkk7jv with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 6
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_052231-txhkk7jv</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/txhkk7jv" target="_blank">polar-sweep-17</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8220917788483246
# 0.6700477120906372
# 0.22959489781881098
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>loss</td><td>▃█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>18</td></tr><tr><td>best_val_loss</td><td>0.00722</td></tr><tr><td>epoch</td><td>28</td></tr><tr><td>loss</td><td>0.02038</td></tr><tr><td>val_loss</td><td>0.00741</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">polar-sweep-17</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/txhkk7jv" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/txhkk7jv</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_052231-txhkk7jv/logs</code>
# wandb: Agent Starting Run: d52plvjy with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 8
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_052307-d52plvjy</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/d52plvjy" target="_blank">treasured-sweep-18</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8108764103830294
# 0.6610876027567657
# 0.23201349904082527
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>▂█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.02209</td></tr><tr><td>val_loss</td><td>0.00831</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">treasured-sweep-18</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/d52plvjy" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/d52plvjy</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_052307-d52plvjy/logs</code>
# wandb: Agent Starting Run: jflwdfij with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 6
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_052332-jflwdfij</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/jflwdfij" target="_blank">quiet-sweep-19</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8079050077962715
# 0.656939736436406
# 0.22984943117151058
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>22</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>32</td></tr><tr><td>loss</td><td>0.02051</td></tr><tr><td>val_loss</td><td>0.00762</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">quiet-sweep-19</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/jflwdfij" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/jflwdfij</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_052332-jflwdfij/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: lii31snm with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 7
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_052414-lii31snm</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/lii31snm" target="_blank">rare-sweep-20</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8153950895720458
# 0.6645395746449708
# 0.23064126963096748
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>29</td></tr><tr><td>loss</td><td>0.02048</td></tr><tr><td>val_loss</td><td>0.00759</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">rare-sweep-20</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/lii31snm" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/lii31snm</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_052414-lii31snm/logs</code>
# wandb: Agent Starting Run: xzvi4wdc with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 9
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_052446-xzvi4wdc</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/xzvi4wdc" target="_blank">sunny-sweep-21</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8280589948071992
# 0.6787221445682784
# 0.23297951718215745
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>10</td></tr><tr><td>best_val_loss</td><td>0.00722</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>0.02132</td></tr><tr><td>val_loss</td><td>0.00755</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sunny-sweep-21</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/xzvi4wdc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/xzvi4wdc</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_052446-xzvi4wdc/logs</code>
# wandb: Agent Starting Run: v40lvlvb with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 7
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_052521-v40lvlvb</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/v40lvlvb" target="_blank">absurd-sweep-22</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8158714781024714
# 0.6649690944769385
# 0.2306285636130944
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# ...
# Find logs at: <code>./wandb/run-20220408_053733-ndeme3ju/logs</code>
# wandb: Agent Starting Run: un6nm9z1 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 5
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_053807-un6nm9z1</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/un6nm9z1" target="_blank">legendary-sweep-44</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8190480080403904
# 0.6666119149046588
# 0.2286544912703641
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▅█▇▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>██▄▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>39</td></tr><tr><td>best_val_loss</td><td>0.00723</td></tr><tr><td>epoch</td><td>49</td></tr><tr><td>loss</td><td>0.02025</td></tr><tr><td>val_loss</td><td>0.0076</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">legendary-sweep-44</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/un6nm9z1" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/un6nm9z1</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_053807-un6nm9z1/logs</code>
# wandb: Agent Starting Run: wwg9l494 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 6
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_053838-wwg9l494</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/wwg9l494" target="_blank">crimson-sweep-45</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8146479929433391
# 0.6636867291438936
# 0.22778192013814136
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄▃█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.00692</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>0.02151</td></tr><tr><td>val_loss</td><td>0.0082</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">crimson-sweep-45</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/wwg9l494" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/wwg9l494</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_053838-wwg9l494/logs</code>
# wandb: Agent Starting Run: rxh1hgfo with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 7
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_053904-rxh1hgfo</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/rxh1hgfo" target="_blank">amber-sweep-46</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8044703784263555
# 0.6550074572103464
# 0.2309757182740337
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>▇█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>21</td></tr><tr><td>best_val_loss</td><td>0.00716</td></tr><tr><td>epoch</td><td>31</td></tr><tr><td>loss</td><td>0.02204</td></tr><tr><td>val_loss</td><td>0.00795</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">amber-sweep-46</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/rxh1hgfo" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/rxh1hgfo</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_053904-rxh1hgfo/logs</code>
# wandb: Agent Starting Run: bzsi0tis with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 7
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_053936-bzsi0tis</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/bzsi0tis" target="_blank">dainty-sweep-47</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.817962675954967
# 0.6669335203161416
# 0.23060892058304583
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>▄█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.02341</td></tr><tr><td>val_loss</td><td>0.00725</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dainty-sweep-47</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/bzsi0tis" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/bzsi0tis</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_053936-bzsi0tis/logs</code>
# wandb: Agent Starting Run: 0pa9zu82 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 8
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_054011-0pa9zu82</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/0pa9zu82" target="_blank">warm-sweep-48</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.7827654534408368
# 0.636602133285987
# 0.22915656318103697
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>18</td></tr><tr><td>best_val_loss</td><td>0.00711</td></tr><tr><td>epoch</td><td>28</td></tr><tr><td>loss</td><td>0.01948</td></tr><tr><td>val_loss</td><td>0.00727</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">warm-sweep-48</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/0pa9zu82" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/0pa9zu82</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_054011-0pa9zu82/logs</code>
# wandb: Agent Starting Run: yrxfvsvr with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 5
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_054042-yrxfvsvr</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/yrxfvsvr" target="_blank">celestial-sweep-49</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.8057048936763646
# 0.654380943486631
# 0.22899857415438274
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.341 MB of 5.341 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>▃█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.0204</td></tr><tr><td>val_loss</td><td>0.00754</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">celestial-sweep-49</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/yrxfvsvr" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/yrxfvsvr</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_054042-yrxfvsvr/logs</code>
# wandb: Agent Starting Run: mg6ffvgb with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	timestep: 8
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_054118-mg6ffvgb</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/mg6ffvgb" target="_blank">trim-sweep-50</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/sweeps/48p0nggc</a>
# 0.814190906323112
# 0.6640435329600735
# 0.2318341991845708
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.314 MB of 2.314 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.0201</td></tr><tr><td>val_loss</td><td>0.00722</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">trim-sweep-50</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/mg6ffvgb" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_RNN/runs/mg6ffvgb</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_054118-mg6ffvgb/logs</code>

# %% [markdown]
# # LSTM

# %%
# Configure the sweep – specify the parameters to search through, the search strategy, the optimization metric et all.
sweep_config = {
    'name': 'LSTM',
    'method': 'bayes', #grid, random
    'metric': {
      'name': 'best_val_loss',
      'goal': 'minimize'   
    },
    'parameters': {
        'batch_size': {
            'values': [256, 128, 64, 32]
        },
        'dropout': {
            'values': [0, 0.1, 0.3]
        },
        'units': {
            'values': [64, 128, 256]
        },
        'timestep': {
            'distribution': "int_uniform",
            'min': 1,
            'max': 12
        },
        'lr': {
            'values': [1e-2, 1e-1]
        },
        'layers': {
            'values': [1, 2, 4, 8]
        },
        'univariate': {
            'values': [False, True]
        },
        'resid': {
            'values': [False, True]
        }
        
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, entity="ancy", project="recifehora_RESIDUAL_LSTM")
# Out:
# Create sweep with ID: v0qkcs0p
# Sweep URL: https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p

# %%
def create_lstm():
    config_defaults = {
    'batch_size': 128,
    'lr': 1e-3,
    'units': 64,
    'timestep': 3,
    'dropout': 0.3,
    'layers': 1,
    'univariate':False,
    'resid': False,
    }

    wandb.init(config=config_defaults)
    config = wandb.config

    batch_size = config.batch_size
    lr         = config.lr
    num_units  = config.units
    timestep   = config.timestep
    dropout    = config.dropout
    layers     = config.layers

    train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y = make_data3(hourly, config.timestep, resid_check=True, resid=config.resid, univariate=config.univariate)
    model = Sequential()

    if layers > 1:
      model.add(LSTM(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout, return_sequences=True))

      for i in range(layers-2):
        model.add(LSTM(units = num_units, dropout=dropout, return_sequences=True))

      model.add(LSTM(units = num_units, dropout=dropout))

    else:
      model.add(LSTM(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout))

    model.add(Dense(units = 1))
    model.compile(
        loss="mse",
        optimizer=Adam(learning_rate=lr)
    )

    model.fit(train_X, train_y, batch_size=batch_size,
              epochs=200, verbose=0, shuffle=False,
              validation_data=(valid_X, valid_y),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=10, restore_best_weights=True)])
    
    yhat = model.predict(test_X)
    yhat_inv = scaler_y.inverse_transform(yhat)
    resid_sum = (yhat_inv+sarima_pred.values[config.timestep:])
    resid_sum2 = (yhat_inv+sarima_pred2.values[config.timestep:])

    wandb.log({"Test_Loss 1": sqrt(mean_squared_error(resid_sum, scaler_y.inverse_transform(test_y)))})
    wandb.log({"Test_Loss 2": sqrt(mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y)))})

    return model

# %%
wandb.agent(sweep_id, create_lstm, count=50)
# Out:
# wandb: Agent Starting Run: 324ilft3 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	resid: False
# wandb: 	timestep: 11
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075041-324ilft3</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/324ilft3" target="_blank">dazzling-sweep-1</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.960 MB of 2.960 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃█▁▁▂▂▂▂▂▃▃▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.04624</td></tr><tr><td>Test_Loss 2</td><td>0.65874</td></tr><tr><td>best_epoch</td><td>2</td></tr><tr><td>best_val_loss</td><td>0.02276</td></tr><tr><td>epoch</td><td>12</td></tr><tr><td>loss</td><td>0.02916</td></tr><tr><td>val_loss</td><td>0.02671</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dazzling-sweep-1</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/324ilft3" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/324ilft3</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075041-324ilft3/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 5wc94lex with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 6
# wandb: 	units: 256
# wandb: 	univariate: True
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075150-5wc94lex</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/5wc94lex" target="_blank">swept-sweep-2</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='21.126 MB of 21.126 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.10215</td></tr><tr><td>Test_Loss 2</td><td>0.67409</td></tr><tr><td>best_epoch</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.02052</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>loss</td><td>0.02266</td></tr><tr><td>val_loss</td><td>0.02066</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">swept-sweep-2</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/5wc94lex" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/5wc94lex</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075150-5wc94lex/logs</code>
# wandb: Agent Starting Run: u8xjrdhl with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	resid: True
# wandb: 	timestep: 9
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075242-u8xjrdhl</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/u8xjrdhl" target="_blank">decent-sweep-3</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.619 MB of 0.619 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.07231</td></tr><tr><td>Test_Loss 2</td><td>0.65458</td></tr><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.02109</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>loss</td><td>0.02319</td></tr><tr><td>val_loss</td><td>0.02459</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">decent-sweep-3</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/u8xjrdhl" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/u8xjrdhl</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075242-u8xjrdhl/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 7e7r8ik4 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	resid: False
# wandb: 	timestep: 8
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075323-7e7r8ik4</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/7e7r8ik4" target="_blank">prime-sweep-4</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.400 MB of 1.400 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁█▃▄▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.08993</td></tr><tr><td>Test_Loss 2</td><td>0.66255</td></tr><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.02069</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.02285</td></tr><tr><td>val_loss</td><td>0.02108</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">prime-sweep-4</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/7e7r8ik4" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/7e7r8ik4</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075323-7e7r8ik4/logs</code>
# wandb: Agent Starting Run: f7d8zw96 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 2
# wandb: 	units: 128
# wandb: 	univariate: True
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075404-f7d8zw96</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/f7d8zw96" target="_blank">fluent-sweep-5</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.792 MB of 0.792 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂█▂▅▁▃▂▁▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.04926</td></tr><tr><td>Test_Loss 2</td><td>0.65775</td></tr><tr><td>best_epoch</td><td>25</td></tr><tr><td>best_val_loss</td><td>0.02097</td></tr><tr><td>epoch</td><td>35</td></tr><tr><td>loss</td><td>0.02249</td></tr><tr><td>val_loss</td><td>0.02103</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fluent-sweep-5</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/f7d8zw96" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/f7d8zw96</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075404-f7d8zw96/logs</code>
# wandb: Agent Starting Run: hxvv1wrt with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	resid: True
# wandb: 	timestep: 10
# wandb: 	units: 256
# wandb: 	univariate: True
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075435-hxvv1wrt</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/hxvv1wrt" target="_blank">classic-sweep-6</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='21.126 MB of 21.126 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂█▃▂▁▁▁▁▁▁▂▄▄▂▁▂▂▄▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.09342</td></tr><tr><td>Test_Loss 2</td><td>0.67962</td></tr><tr><td>best_epoch</td><td>8</td></tr><tr><td>best_val_loss</td><td>0.02139</td></tr><tr><td>epoch</td><td>18</td></tr><tr><td>loss</td><td>0.05933</td></tr><tr><td>val_loss</td><td>0.04422</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">classic-sweep-6</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/hxvv1wrt" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/hxvv1wrt</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075435-hxvv1wrt/logs</code>
# wandb: Agent Starting Run: 0dxctztf with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	resid: True
# wandb: 	timestep: 6
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075627-0dxctztf</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/0dxctztf" target="_blank">wise-sweep-7</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.619 MB of 0.619 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.09197</td></tr><tr><td>Test_Loss 2</td><td>0.65963</td></tr><tr><td>best_epoch</td><td>10</td></tr><tr><td>best_val_loss</td><td>0.02049</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>0.02291</td></tr><tr><td>val_loss</td><td>0.02185</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">wise-sweep-7</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/0dxctztf" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/0dxctztf</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075627-0dxctztf/logs</code>
# wandb: Agent Starting Run: u2zte9gj with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 5
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075658-u2zte9gj</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/u2zte9gj" target="_blank">winter-sweep-8</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.232 MB of 0.232 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▂▂▂▂▂▂▁▁▁▁▁▂▂▂▂▁▁▂▂▁▁▂▂▁▁▂▁▁▂▂▁▁▁▂▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.02823</td></tr><tr><td>Test_Loss 2</td><td>0.6363</td></tr><tr><td>best_epoch</td><td>47</td></tr><tr><td>best_val_loss</td><td>0.01887</td></tr><tr><td>epoch</td><td>57</td></tr><tr><td>loss</td><td>0.0198</td></tr><tr><td>val_loss</td><td>0.01999</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">winter-sweep-8</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/u2zte9gj" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/u2zte9gj</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075658-u2zte9gj/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: lrfvrzcy with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	resid: False
# wandb: 	timestep: 12
# wandb: 	units: 128
# wandb: 	univariate: True
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075739-lrfvrzcy</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/lrfvrzcy" target="_blank">solar-sweep-9</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.345 MB of 5.345 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.05646</td></tr><tr><td>Test_Loss 2</td><td>0.66164</td></tr><tr><td>best_epoch</td><td>25</td></tr><tr><td>best_val_loss</td><td>0.02095</td></tr><tr><td>epoch</td><td>35</td></tr><tr><td>loss</td><td>0.02245</td></tr><tr><td>val_loss</td><td>0.02162</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">solar-sweep-9</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/lrfvrzcy" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/lrfvrzcy</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075739-lrfvrzcy/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 9wcdbnas with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	resid: True
# wandb: 	timestep: 11
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075901-9wcdbnas</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/9wcdbnas" target="_blank">treasured-sweep-10</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.619 MB of 0.619 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>██▁▂▁▁▁▁▁▁▁▁▁▁▁▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.0652</td></tr><tr><td>Test_Loss 2</td><td>0.66024</td></tr><tr><td>best_epoch</td><td>8</td></tr><tr><td>best_val_loss</td><td>0.02092</td></tr><tr><td>epoch</td><td>18</td></tr><tr><td>loss</td><td>0.02301</td></tr><tr><td>val_loss</td><td>0.02377</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">treasured-sweep-10</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/9wcdbnas" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/9wcdbnas</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075901-9wcdbnas/logs</code>
# wandb: Agent Starting Run: t2e4j86g with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	resid: True
# wandb: 	timestep: 2
# wandb: 	units: 128
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_075937-t2e4j86g</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/t2e4j86g" target="_blank">lunar-sweep-11</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.325 MB of 2.325 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▄▄▄▅▅▅▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▇▆▃▃▁▂▁▁▁▁▃▆▇▆▅█▆▅▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.04221</td></tr><tr><td>Test_Loss 2</td><td>0.64559</td></tr><tr><td>best_epoch</td><td>9</td></tr><tr><td>best_val_loss</td><td>0.02115</td></tr><tr><td>epoch</td><td>19</td></tr><tr><td>loss</td><td>0.03358</td></tr><tr><td>val_loss</td><td>0.03991</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">lunar-sweep-11</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/t2e4j86g" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/t2e4j86g</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_075937-t2e4j86g/logs</code>
# wandb: Agent Starting Run: 48w4cj78 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 7
# wandb: 	units: 128
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_080008-48w4cj78</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/48w4cj78" target="_blank">golden-sweep-12</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.325 MB of 2.325 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▅▁▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.04941</td></tr><tr><td>Test_Loss 2</td><td>0.66059</td></tr><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.02067</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>loss</td><td>0.02251</td></tr><tr><td>val_loss</td><td>0.02095</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">golden-sweep-12</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/48w4cj78" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/48w4cj78</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_080008-48w4cj78/logs</code>
# wandb: Agent Starting Run: lslu677b with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 1
# wandb: 	lr: 0.1
# wandb: 	resid: True
# wandb: 	timestep: 3
# wandb: 	units: 128
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_080040-lslu677b</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/lslu677b" target="_blank">classic-sweep-13</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.810 MB of 0.810 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▃▃▄▄▄▄▅▅▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.02454</td></tr><tr><td>Test_Loss 2</td><td>0.64759</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.0213</td></tr><tr><td>epoch</td><td>13</td></tr><tr><td>loss</td><td>0.02545</td></tr><tr><td>val_loss</td><td>0.03186</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">classic-sweep-13</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/lslu677b" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/lslu677b</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_080040-lslu677b/logs</code>
# wandb: Agent Starting Run: ysdwoqat with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	resid: True
# wandb: 	timestep: 8
# wandb: 	units: 128
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_080106-ysdwoqat</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/ysdwoqat" target="_blank">icy-sweep-14</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.06542</td></tr><tr><td>Test_Loss 2</td><td>0.65355</td></tr><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.02184</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>0.0238</td></tr><tr><td>val_loss</td><td>0.02534</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">icy-sweep-14</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/ysdwoqat" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/ysdwoqat</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_080106-ysdwoqat/logs</code>
# wandb: Agent Starting Run: 17w5asna with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 3
# wandb: 	units: 128
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_080143-17w5asna</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/17w5asna" target="_blank">iconic-sweep-15</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.810 MB of 0.810 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▂▁▁▁▁▁▁▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.00657</td></tr><tr><td>Test_Loss 2</td><td>0.65112</td></tr><tr><td>best_epoch</td><td>5</td></tr><tr><td>best_val_loss</td><td>0.02074</td></tr><tr><td>epoch</td><td>15</td></tr><tr><td>loss</td><td>0.02152</td></tr><tr><td>val_loss</td><td>0.02084</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">iconic-sweep-15</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/17w5asna" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/17w5asna</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_080143-17w5asna/logs</code>
# wandb: Agent Starting Run: 4m3r8bjn with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 7
# wandb: 	units: 64
# wandb: 	univariate: True
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_080209-4m3r8bjn</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/4m3r8bjn" target="_blank">young-sweep-16</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.611 MB of 0.611 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.08147</td></tr><tr><td>Test_Loss 2</td><td>0.6579</td></tr><tr><td>best_epoch</td><td>22</td></tr><tr><td>best_val_loss</td><td>0.02068</td></tr><tr><td>epoch</td><td>32</td></tr><tr><td>loss</td><td>0.02288</td></tr><tr><td>val_loss</td><td>0.02075</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">young-sweep-16</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/4m3r8bjn" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/4m3r8bjn</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_080209-4m3r8bjn/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: yu4z1i5w with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 1
# wandb: 	lr: 0.1
# wandb: 	resid: True
# wandb: 	timestep: 5
# wandb: 	units: 64
# wandb: 	univariate: True
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_080251-yu4z1i5w</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/yu4z1i5w" target="_blank">pious-sweep-17</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.223 MB of 0.223 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.09728</td></tr><tr><td>Test_Loss 2</td><td>0.66325</td></tr><tr><td>best_epoch</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.02051</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>loss</td><td>0.02358</td></tr><tr><td>val_loss</td><td>0.02077</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">pious-sweep-17</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/yu4z1i5w" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/yu4z1i5w</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_080251-yu4z1i5w/logs</code>
# wandb: Agent Starting Run: 4mnhqlg5 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 8
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_080318-4mnhqlg5</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/4mnhqlg5" target="_blank">polar-sweep-18</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.619 MB of 0.619 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▅█▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▂▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.05294</td></tr><tr><td>Test_Loss 2</td><td>0.64471</td></tr><tr><td>best_epoch</td><td>48</td></tr><tr><td>best_val_loss</td><td>0.01898</td></tr><tr><td>epoch</td><td>58</td></tr><tr><td>loss</td><td>0.02071</td></tr><tr><td>val_loss</td><td>0.02005</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">polar-sweep-18</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/4mnhqlg5" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/4mnhqlg5</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_080318-4mnhqlg5/logs</code>
# wandb: Agent Starting Run: ltiy658d with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 7
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_080355-ltiy658d</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/ltiy658d" target="_blank">dauntless-sweep-19</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.619 MB of 0.619 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▅█▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▂▂▂▁▁▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.02856</td></tr><tr><td>Test_Loss 2</td><td>0.64016</td></tr><tr><td>best_epoch</td><td>32</td></tr><tr><td>best_val_loss</td><td>0.01882</td></tr><tr><td>epoch</td><td>42</td></tr><tr><td>loss</td><td>0.02057</td></tr><tr><td>val_loss</td><td>0.01986</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dauntless-sweep-19</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/ltiy658d" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/ltiy658d</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_080355-ltiy658d/logs</code>
# wandb: Agent Starting Run: p8ah5eof with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 5
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_080434-p8ah5eof</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/p8ah5eof" target="_blank">happy-sweep-20</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.232 MB of 0.232 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▆█▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.08313</td></tr><tr><td>Test_Loss 2</td><td>0.6476</td></tr><tr><td>best_epoch</td><td>41</td></tr><tr><td>best_val_loss</td><td>0.01964</td></tr><tr><td>epoch</td><td>51</td></tr><tr><td>loss</td><td>0.02136</td></tr><tr><td>val_loss</td><td>0.02077</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">happy-sweep-20</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/p8ah5eof" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/p8ah5eof</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# ...
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▂▂▃▃▄▄▅▅▆▆▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▆▄█▁▃▃▄▄▄▄▃▄▃▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.01623</td></tr><tr><td>Test_Loss 2</td><td>0.65183</td></tr><tr><td>best_epoch</td><td>3</td></tr><tr><td>best_val_loss</td><td>0.02006</td></tr><tr><td>epoch</td><td>13</td></tr><tr><td>loss</td><td>0.02099</td></tr><tr><td>val_loss</td><td>0.02589</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dulcet-sweep-44</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/h33f2ded" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/h33f2ded</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_081902-h33f2ded/logs</code>
# wandb: Agent Starting Run: 1q091ai7 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 7
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_081933-1q091ai7</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/1q091ai7" target="_blank">daily-sweep-45</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.232 MB of 0.232 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>loss</td><td>█▆▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▂▁▁▁▂▁▁▁▂▂▁▁▁▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.05011</td></tr><tr><td>Test_Loss 2</td><td>0.64047</td></tr><tr><td>best_epoch</td><td>30</td></tr><tr><td>best_val_loss</td><td>0.01888</td></tr><tr><td>epoch</td><td>40</td></tr><tr><td>loss</td><td>0.02069</td></tr><tr><td>val_loss</td><td>0.01897</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">daily-sweep-45</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/1q091ai7" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/1q091ai7</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_081933-1q091ai7/logs</code>
# wandb: Agent Starting Run: 30ed6wwy with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.1
# wandb: 	resid: True
# wandb: 	timestep: 7
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_082008-30ed6wwy</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/30ed6wwy" target="_blank">autumn-sweep-46</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.619 MB of 0.619 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▃▃▃▄▅▅▅▆▇▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▁▁▁▁▂▃▃▄▃▃▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.07494</td></tr><tr><td>Test_Loss 2</td><td>0.65322</td></tr><tr><td>best_epoch</td><td>4</td></tr><tr><td>best_val_loss</td><td>0.02091</td></tr><tr><td>epoch</td><td>14</td></tr><tr><td>loss</td><td>0.02311</td></tr><tr><td>val_loss</td><td>0.02452</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">autumn-sweep-46</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/30ed6wwy" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/30ed6wwy</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_082008-30ed6wwy/logs</code>
# wandb: Agent Starting Run: rb3gazjw with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 8
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_082043-rb3gazjw</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/rb3gazjw" target="_blank">laced-sweep-47</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.232 MB of 0.232 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>██▃▃▃▂▂▂▂▂▂▂▁▁▂▂▁▁▁▂▁▁▁▁▂▁▁▁▁▁▁▁▂▄▃▂▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>0.99701</td></tr><tr><td>Test_Loss 2</td><td>0.6162</td></tr><tr><td>best_epoch</td><td>28</td></tr><tr><td>best_val_loss</td><td>0.01873</td></tr><tr><td>epoch</td><td>38</td></tr><tr><td>loss</td><td>0.01699</td></tr><tr><td>val_loss</td><td>0.02068</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">laced-sweep-47</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/rb3gazjw" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/rb3gazjw</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_082043-rb3gazjw/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: mvpuekd8 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.1
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 6
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_082129-mvpuekd8</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/mvpuekd8" target="_blank">wandering-sweep-48</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄█▇▂▂▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▂▁▁▃▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.05059</td></tr><tr><td>Test_Loss 2</td><td>0.63971</td></tr><tr><td>best_epoch</td><td>43</td></tr><tr><td>best_val_loss</td><td>0.01923</td></tr><tr><td>epoch</td><td>53</td></tr><tr><td>loss</td><td>0.02019</td></tr><tr><td>val_loss</td><td>0.01975</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">wandering-sweep-48</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/mvpuekd8" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/mvpuekd8</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_082129-mvpuekd8/logs</code>
# wandb: Agent Starting Run: w190h0wj with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0
# wandb: 	layers: 1
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 9
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_082159-w190h0wj</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/w190h0wj" target="_blank">cosmic-sweep-49</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.232 MB of 0.232 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>██▆▆▄▃▃▃▃▃▃▃▂▃▅▂▃▃▂▄▂▂▁▁▃▅▂▁▂▁▃▂▂▅▃▁▃▄▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.0192</td></tr><tr><td>Test_Loss 2</td><td>0.62</td></tr><tr><td>best_epoch</td><td>40</td></tr><tr><td>best_val_loss</td><td>0.01848</td></tr><tr><td>epoch</td><td>50</td></tr><tr><td>loss</td><td>0.01743</td></tr><tr><td>val_loss</td><td>0.01955</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">cosmic-sweep-49</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/w190h0wj" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/w190h0wj</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_082159-w190h0wj/logs</code>
# wandb: Agent Starting Run: ztnx7sng with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	layers: 2
# wandb: 	lr: 0.01
# wandb: 	resid: True
# wandb: 	timestep: 5
# wandb: 	units: 64
# wandb: 	univariate: False
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_082230-ztnx7sng</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/ztnx7sng" target="_blank">vital-sweep-50</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/sweeps/v0qkcs0p</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.619 MB of 0.619 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄█▂▂▂▂▂▂▂▂▂▁▁▁▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.07529</td></tr><tr><td>Test_Loss 2</td><td>0.63812</td></tr><tr><td>best_epoch</td><td>47</td></tr><tr><td>best_val_loss</td><td>0.01887</td></tr><tr><td>epoch</td><td>57</td></tr><tr><td>loss</td><td>0.02028</td></tr><tr><td>val_loss</td><td>0.02131</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">vital-sweep-50</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/ztnx7sng" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_LSTM/runs/ztnx7sng</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_082230-ztnx7sng/logs</code>

# %% [markdown]
# # GRU

# %%
# Configure the sweep – specify the parameters to search through, the search strategy, the optimization metric et all.
sweep_config = {
    'name': 'GRU',
    'method': 'bayes', #grid, random
    'metric': {
      'name': 'best_val_loss',
      'goal': 'minimize'   
    },
    'parameters': {
        'batch_size': {
            'values': [256, 128, 64, 32]
        },
        'dropout': {
            'values': [0, 0.1, 0.3]
        },
        'units': {
            'values': [64, 128, 256]
        },
        'timestep': {
            'distribution': "int_uniform",
            'min': 1,
            'max': 12
        },
        'lr': {
            'values': [1e-2, 1e-1]
        },
        'layers': {
            'values': [1, 2, 4, 8]
        },
        
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, entity="ancy", project="recifehora_RESIDUAL_GRU")
# Out:
# Create sweep with ID: ubqjlnjp
# Sweep URL: https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp

# %%
def create_gru():
    config_defaults = {
    'batch_size': 128,
    'lr': 1e-3,
    'units': 64,
    'timestep': 3,
    'dropout': 0.3,
    'layers': 1,
    }

    wandb.init(config=config_defaults)
    config = wandb.config

    batch_size = config.batch_size
    lr         = config.lr
    num_units  = config.units
    timestep   = config.timestep
    dropout    = config.dropout
    layers     = config.layers

    train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y = make_data2(hourly, timestep, resid_check=True)
    model = Sequential()

    if layers > 1:
      model.add(GRU(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout, return_sequences=True))

      for i in range(layers-2):
        model.add(GRU(units = num_units, dropout=dropout, return_sequences=True))

      model.add(GRU(units = num_units, dropout=dropout))

    else:
      model.add(GRU(units = num_units, input_shape=(train_X.shape[1], train_X.shape[2]), dropout=dropout))

    model.add(Dense(units = 1))
    lr = config.lr
    model.compile(
        loss="mse",
        optimizer=Adam(learning_rate=lr)
    )
    
    model.fit(train_X, train_y, batch_size=config.batch_size,
              epochs=200, verbose=0, shuffle=False,
              validation_data=(valid_X, valid_y),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=10, restore_best_weights=True), ReduceLROnPlateau(monitor='val_loss',patience=5, min_lr=1e-6)])
    
    yhat = model.predict(test_X)
    yhat_inv = scaler_y.inverse_transform(yhat)
    resid_sum = (yhat_inv+sarima_pred.values[config.timestep:])

    print(sqrt(mean_squared_error(resid_sum, scaler_y.inverse_transform(test_y))))
    print(mean_absolute_error(resid_sum, scaler_y.inverse_transform(test_y)))
    print(mean_absolute_percentage_error(resid_sum, scaler_y.inverse_transform(test_y)))

    return model

# %%
wandb.agent(sweep_id, create_gru, count=50)
# Out:
# wandb: Agent Starting Run: hlrdke10 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.1
# wandb: 	layers: 1
# wandb: 	lr: 0.1
# wandb: 	timestep: 4
# wandb: 	units: 64
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_062655-hlrdke10</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/hlrdke10" target="_blank">playful-sweep-1</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8248587283554925
# 0.6673677413084929
# 0.27461373858811955
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.183 MB of 0.183 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>25</td></tr><tr><td>best_val_loss</td><td>0.00989</td></tr><tr><td>epoch</td><td>35</td></tr><tr><td>loss</td><td>0.02548</td></tr><tr><td>val_loss</td><td>0.01007</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">playful-sweep-1</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/hlrdke10" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/hlrdke10</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_062655-hlrdke10/logs</code>
# wandb: Agent Starting Run: cwst2guv with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 4
# wandb: 	units: 64
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_062720-cwst2guv</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/cwst2guv" target="_blank">sunny-sweep-2</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.816740719044784
# 0.6651484322819726
# 0.2290965691765442
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.078 MB of 1.078 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▅▇▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▇█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>8</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>18</td></tr><tr><td>loss</td><td>0.02204</td></tr><tr><td>val_loss</td><td>0.00762</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sunny-sweep-2</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/cwst2guv" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/cwst2guv</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_062720-cwst2guv/logs</code>
# wandb: Agent Starting Run: 0xpkhwby with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 5
# wandb: 	units: 64
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_062754-0xpkhwby</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/0xpkhwby" target="_blank">magic-sweep-3</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8109953402439483
# 0.6590832917135857
# 0.22862014874350184
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.078 MB of 1.078 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>23</td></tr><tr><td>loss</td><td>0.01999</td></tr><tr><td>val_loss</td><td>0.00758</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">magic-sweep-3</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/0xpkhwby" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/0xpkhwby</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_062754-0xpkhwby/logs</code>
# wandb: Agent Starting Run: csijptul with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 6
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_062829-csijptul</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/csijptul" target="_blank">faithful-sweep-4</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8138801555507977
# 0.662307992337904
# 0.22955951000959673
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.056 MB of 4.056 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>17</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>27</td></tr><tr><td>loss</td><td>0.02004</td></tr><tr><td>val_loss</td><td>0.00772</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">faithful-sweep-4</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/csijptul" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/csijptul</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_062829-csijptul/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: hb4k3fbj with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 5
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_062932-hb4k3fbj</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/hb4k3fbj" target="_blank">crisp-sweep-5</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8210662922465277
# 0.6684454405877596
# 0.22862973241069925
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.056 MB of 4.056 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>20</td></tr><tr><td>best_val_loss</td><td>0.00723</td></tr><tr><td>epoch</td><td>30</td></tr><tr><td>loss</td><td>0.02</td></tr><tr><td>val_loss</td><td>0.0077</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">crisp-sweep-5</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/hb4k3fbj" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/hb4k3fbj</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_062932-hb4k3fbj/logs</code>
# wandb: Agent Starting Run: 7s62ahcp with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 8
# wandb: 	units: 64
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_063013-7s62ahcp</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/7s62ahcp" target="_blank">dashing-sweep-6</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.823919382989684
# 0.6731936993199978
# 0.23163743647311416
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.272 MB of 2.272 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>▂█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.00722</td></tr><tr><td>epoch</td><td>23</td></tr><tr><td>loss</td><td>0.02828</td></tr><tr><td>val_loss</td><td>0.00809</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dashing-sweep-6</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/7s62ahcp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/7s62ahcp</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_063013-7s62ahcp/logs</code>
# wandb: Agent Starting Run: wumqed7d with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 5
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_063109-wumqed7d</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/wumqed7d" target="_blank">skilled-sweep-7</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8325070263982767
# 0.6798399038656447
# 0.22926578289825397
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.639 MB of 8.639 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>loss</td><td>▂█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>32</td></tr><tr><td>best_val_loss</td><td>0.00729</td></tr><tr><td>epoch</td><td>42</td></tr><tr><td>loss</td><td>0.02084</td></tr><tr><td>val_loss</td><td>0.00748</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">skilled-sweep-7</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/wumqed7d" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/wumqed7d</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_063109-wumqed7d/logs</code>
# wandb: Agent Starting Run: wi1rof9e with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 4
# wandb: 	units: 64
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_063210-wi1rof9e</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/wi1rof9e" target="_blank">proud-sweep-8</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8173157223763141
# 0.6657243869803262
# 0.22910926846785815
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.272 MB of 2.272 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>16</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>26</td></tr><tr><td>loss</td><td>0.02004</td></tr><tr><td>val_loss</td><td>0.00785</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">proud-sweep-8</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/wi1rof9e" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/wi1rof9e</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_063210-wi1rof9e/logs</code>
# wandb: Agent Starting Run: 61lc558v with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 3
# wandb: 	units: 64
# wandb: W&B API key is configured (use `wandb login --relogin` to force relogin)
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_063305-61lc558v</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/61lc558v" target="_blank">smart-sweep-9</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8043166297077262
# 0.6547771402350108
# 0.2312857679666188
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.272 MB of 2.272 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>▁█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>11</td></tr><tr><td>best_val_loss</td><td>0.00722</td></tr><tr><td>epoch</td><td>21</td></tr><tr><td>loss</td><td>0.02048</td></tr><tr><td>val_loss</td><td>0.00928</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">smart-sweep-9</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/61lc558v" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/61lc558v</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_063305-61lc558v/logs</code>
# wandb: Agent Starting Run: 1ii1f99f with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.1
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 7
# wandb: 	units: 64
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_063352-1ii1f99f</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/1ii1f99f" target="_blank">dry-sweep-10</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.7897182630584186
# 0.6403206102620675
# 0.23371140616236022
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.272 MB of 2.272 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▅▆▆▆▇▇▇▇▇██</td></tr><tr><td>loss</td><td>▆█▆▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>18</td></tr><tr><td>best_val_loss</td><td>0.0074</td></tr><tr><td>epoch</td><td>28</td></tr><tr><td>loss</td><td>0.02004</td></tr><tr><td>val_loss</td><td>0.0079</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dry-sweep-10</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/1ii1f99f" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/1ii1f99f</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_063352-1ii1f99f/logs</code>
# wandb: Agent Starting Run: zzwibn2j with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 10
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_063443-zzwibn2j</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/zzwibn2j" target="_blank">gentle-sweep-11</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8238913180926937
# 0.6744557524417979
# 0.23364297126162867
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='34.040 MB of 34.040 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.00718</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>loss</td><td>0.02195</td></tr><tr><td>val_loss</td><td>0.00787</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">gentle-sweep-11</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/zzwibn2j" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/zzwibn2j</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_063443-zzwibn2j/logs</code>
# wandb: Agent Starting Run: 6czz0kth with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 10
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_063645-6czz0kth</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/6czz0kth" target="_blank">generous-sweep-12</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8108425803519724
# 0.6619942861377751
# 0.2342191755199634
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.639 MB of 8.639 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.00723</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.0297</td></tr><tr><td>val_loss</td><td>0.00782</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">generous-sweep-12</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/6czz0kth" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/6czz0kth</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_063645-6czz0kth/logs</code>
# wandb: Agent Starting Run: 8kcz25i6 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 3
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_063756-8kcz25i6</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/8kcz25i6" target="_blank">confused-sweep-13</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8104825742128531
# 0.6603242866162001
# 0.2306650318216469
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='34.040 MB of 34.040 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.02002</td></tr><tr><td>val_loss</td><td>0.00766</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">confused-sweep-13</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/8kcz25i6" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/8kcz25i6</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_063756-8kcz25i6/logs</code>
# wandb: Agent Starting Run: yo2jdobn with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 3
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_063919-yo2jdobn</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/yo2jdobn" target="_blank">likely-sweep-14</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8019320642619923
# 0.652602060491998
# 0.23152329658279064
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='34.040 MB of 34.040 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>12</td></tr><tr><td>best_val_loss</td><td>0.00722</td></tr><tr><td>epoch</td><td>22</td></tr><tr><td>loss</td><td>0.01996</td></tr><tr><td>val_loss</td><td>0.00753</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">likely-sweep-14</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/yo2jdobn" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/yo2jdobn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_063919-yo2jdobn/logs</code>
# wandb: Agent Starting Run: 5jpb8iq1 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 11
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_064035-5jpb8iq1</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/5jpb8iq1" target="_blank">swept-sweep-15</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.799267290336382
# 0.6435200731126889
# 0.23177071541473326
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.639 MB of 8.639 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▃▄▄▄▅▅▅▆▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂█▃▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>13</td></tr><tr><td>best_val_loss</td><td>0.00752</td></tr><tr><td>epoch</td><td>23</td></tr><tr><td>loss</td><td>0.0199</td></tr><tr><td>val_loss</td><td>0.00754</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">swept-sweep-15</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/5jpb8iq1" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/5jpb8iq1</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_064035-5jpb8iq1/logs</code>
# wandb: Agent Starting Run: xle3gdxg with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 1
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_064156-xle3gdxg</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/xle3gdxg" target="_blank">genial-sweep-16</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.7857087096509744
# 0.6369223107821493
# 0.22433771417988918
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='6.365 MB of 6.365 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>▆█▂▁▁▁▁▁▁▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>14</td></tr><tr><td>best_val_loss</td><td>0.00687</td></tr><tr><td>epoch</td><td>24</td></tr><tr><td>loss</td><td>0.02064</td></tr><tr><td>val_loss</td><td>0.00713</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">genial-sweep-16</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/xle3gdxg" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/xle3gdxg</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_064156-xle3gdxg/logs</code>
# wandb: Agent Starting Run: g16uxwe1 with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 3
# wandb: 	units: 256
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_064242-g16uxwe1</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/g16uxwe1" target="_blank">clear-sweep-17</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 1.6684428989851332
# 1.4915939421705158
# 2.2244598189158875
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='34.040 MB of 34.040 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, m…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▂▃▄▅▅▆▇▇█</td></tr><tr><td>loss</td><td>▁▅▆▆█▆▂▂▁▁▁</td></tr><tr><td>val_loss</td><td>▁▇█▁█▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>0.05519</td></tr><tr><td>epoch</td><td>10</td></tr><tr><td>loss</td><td>0.30356</td></tr><tr><td>val_loss</td><td>0.25923</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">clear-sweep-17</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/g16uxwe1" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/g16uxwe1</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_064242-g16uxwe1/logs</code>
# wandb: Agent Starting Run: i3bwxfx2 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 1
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_064333-i3bwxfx2</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/i3bwxfx2" target="_blank">neat-sweep-18</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8025534783898414
# 0.651587286970812
# 0.2352775362662712
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.639 MB of 8.639 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▅▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▇▄▁▄▃▁▂▁▁▂▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.00725</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>0.01972</td></tr><tr><td>val_loss</td><td>0.00743</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">neat-sweep-18</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/i3bwxfx2" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/i3bwxfx2</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_064333-i3bwxfx2/logs</code>
# wandb: Agent Starting Run: qaftc4ax with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 2
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_064419-qaftc4ax</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/qaftc4ax" target="_blank">legendary-sweep-19</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8098871760093198
# 0.6596556492562531
# 0.23552963276646413
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.056 MB of 4.056 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▆▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.00722</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.02631</td></tr><tr><td>val_loss</td><td>0.00995</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">legendary-sweep-19</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/qaftc4ax" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/qaftc4ax</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_064419-qaftc4ax/logs</code>
# wandb: Agent Starting Run: 35p9a7af with config:
# wandb: 	batch_size: 256
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 2
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_064500-35p9a7af</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/35p9a7af" target="_blank">cerulean-sweep-20</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8091519244194243
# 0.65896477896555
# 0.23564222136725663
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.639 MB of 8.639 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.00722</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.02063</td></tr><tr><td>val_loss</td><td>0.00857</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">cerulean-sweep-20</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/35p9a7af" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/35p9a7af</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_064500-35p9a7af/logs</code>
# wandb: Agent Starting Run: d0l0gs0f with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 1
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_064601-d0l0gs0f</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/d0l0gs0f" target="_blank">snowy-sweep-21</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8378910880402919
# 0.6859961008963688
# 0.23358967872561545
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.639 MB of 8.639 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▂▃▄▄▅▅▆▇▇█</td></tr><tr><td>loss</td><td>▄█▁▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▁█▄▁▂▃▃▃▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>1</td></tr><tr><td>best_val_loss</td><td>0.00731</td></tr><tr><td>epoch</td><td>11</td></tr><tr><td>loss</td><td>0.07431</td></tr><tr><td>val_loss</td><td>0.05407</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">snowy-sweep-21</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/d0l0gs0f" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/d0l0gs0f</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_064601-d0l0gs0f/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 7b59jzzq with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 3
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_064657-7b59jzzq</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/7b59jzzq" target="_blank">golden-sweep-22</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8049959525118486
# 0.6553988714601067
# 0.23120738305695787
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.639 MB of 8.639 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
# ...
# Synced <strong style="color:#cdcd00">copper-sweep-43</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/s6myp54p" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/s6myp54p</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_070740-s6myp54p/logs</code>
# wandb: Agent Starting Run: fp1xbai6 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 2
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_070831-fp1xbai6</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/fp1xbai6" target="_blank">ethereal-sweep-44</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8330218659417148
# 0.6830095850507283
# 0.23444638453060912
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.639 MB of 8.639 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.00714</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>loss</td><td>0.02095</td></tr><tr><td>val_loss</td><td>0.00753</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ethereal-sweep-44</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/fp1xbai6" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/fp1xbai6</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_070831-fp1xbai6/logs</code>
# wandb: Agent Starting Run: 03ht4mkn with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.01
# wandb: 	timestep: 1
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_070917-03ht4mkn</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/03ht4mkn" target="_blank">sandy-sweep-45</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8243862552253671
# 0.67268180664104
# 0.23304078490785954
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.639 MB of 8.639 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▂▃▄▅▅▆▇▇█</td></tr><tr><td>loss</td><td>█▁▁▁▂▂▂▂▁▁▁</td></tr><tr><td>val_loss</td><td>▁▅▃▅▃█▆▃▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>0</td></tr><tr><td>best_val_loss</td><td>0.00721</td></tr><tr><td>epoch</td><td>10</td></tr><tr><td>loss</td><td>0.02155</td></tr><tr><td>val_loss</td><td>0.00971</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sandy-sweep-45</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/03ht4mkn" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/03ht4mkn</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_070917-03ht4mkn/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 1bcc3ggw with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.1
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 2
# wandb: 	units: 64
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_071012-1bcc3ggw</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/1bcc3ggw" target="_blank">confused-sweep-46</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.807298570215076
# 0.6572024576374674
# 0.23594379499455992
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▁▃▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>5</td></tr><tr><td>best_val_loss</td><td>0.00723</td></tr><tr><td>epoch</td><td>15</td></tr><tr><td>loss</td><td>0.02004</td></tr><tr><td>val_loss</td><td>0.00785</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">confused-sweep-46</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/1bcc3ggw" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/1bcc3ggw</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_071012-1bcc3ggw/logs</code>
# wandb: Agent Starting Run: n2qbds8q with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.1
# wandb: 	timestep: 1
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_071059-n2qbds8q</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/n2qbds8q" target="_blank">swept-sweep-47</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8065228908069261
# 0.6553178448509942
# 0.23457277249691486
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.056 MB of 4.056 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▇▁█▁▁▅▄▁▃▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.00722</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>0.02</td></tr><tr><td>val_loss</td><td>0.00765</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">swept-sweep-47</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/n2qbds8q" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/n2qbds8q</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_071059-n2qbds8q/logs</code>
# wandb: Agent Starting Run: u7p8obid with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 1
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_071135-u7p8obid</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/u7p8obid" target="_blank">restful-sweep-48</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8344351146918831
# 0.6826394333487562
# 0.2334869184777459
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='8.639 MB of 8.639 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>▄▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>14</td></tr><tr><td>best_val_loss</td><td>0.00729</td></tr><tr><td>epoch</td><td>24</td></tr><tr><td>loss</td><td>0.02</td></tr><tr><td>val_loss</td><td>0.00767</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">restful-sweep-48</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/u7p8obid" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/u7p8obid</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_071135-u7p8obid/logs</code>
# wandb: Agent Starting Run: wgb9o1nf with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 8
# wandb: 	lr: 0.1
# wandb: 	timestep: 2
# wandb: 	units: 64
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_071221-wgb9o1nf</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/wgb9o1nf" target="_blank">feasible-sweep-49</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.8260633811062493
# 0.674785350737643
# 0.2342455448377584
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.272 MB of 2.272 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>8</td></tr><tr><td>best_val_loss</td><td>0.00723</td></tr><tr><td>epoch</td><td>18</td></tr><tr><td>loss</td><td>0.01999</td></tr><tr><td>val_loss</td><td>0.0076</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">feasible-sweep-49</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/wgb9o1nf" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/wgb9o1nf</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_071221-wgb9o1nf/logs</code>
# wandb: Agent Starting Run: 44k8w5v4 with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	layers: 4
# wandb: 	lr: 0.01
# wandb: 	timestep: 1
# wandb: 	units: 128
# Tracking run with wandb version 0.12.13
# Run data is saved locally in <code>/content/wandb/run-20220408_071309-44k8w5v4</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/44k8w5v4" target="_blank">rose-sweep-50</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/sweeps/ubqjlnjp</a>
# 0.7636298849622557
# 0.6184086549606715
# 0.22597705289370987
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.056 MB of 4.056 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▅▃▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_epoch</td><td>17</td></tr><tr><td>best_val_loss</td><td>0.00645</td></tr><tr><td>epoch</td><td>27</td></tr><tr><td>loss</td><td>0.01839</td></tr><tr><td>val_loss</td><td>0.00686</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">rose-sweep-50</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/44k8w5v4" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_GRU/runs/44k8w5v4</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220408_071309-44k8w5v4/logs</code>

# %% [markdown]
# # Transformer

# %%
sweep_config = {
    'name': 'New_Transformer',
    'method': 'bayes', #grid, random
    'metric': {
      'name': 'best_val_loss',
      'goal': 'minimize'   
    },
    'parameters': {
        'batch_size': {
            'values': [128, 64, 32]
        },
        'dropout': {
            'values': [0, 0.1, 0.3]
        },
        'timestep': {
            'distribution': "int_uniform",
            'min': 1,
            'max': 12
        },
        'n_heads': {
            'values': [2, 4, 8]
        },
        'ff_dim': {
            'values': [128,256]
        },
        'n_blocks': {
            'values': [2, 4, 8]
        },
        'embed_dim': {
            'values': [32, 64, 128]
        },
        'time_2_vec': {
            'values': [2,3,4]
        }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, entity="ancy", project="recifehora_RESIDUAL_TRANS")
# Out:
# Create sweep with ID: f9vlkjhp
# Sweep URL: https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp

# %%
class TransformerBlock(layers.Layer):
    def __init__(self, embed_dim, feat_dim, num_heads, ff_dim, rate = 0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads = num_heads, key_dim = embed_dim)
        self.ffn = keras.Sequential( [layers.Dense(ff_dim, activation = "gelu"), layers.Dense(feat_dim),] )
        self.layernorm1 = layers.BatchNormalization()
        self.layernorm2 = layers.BatchNormalization()
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)
        self.embed_dim = embed_dim
        self.feat_dim = feat_dim
        self.num_heads = num_heads
        self.ff_dim = ff_dim
        self.rate = rate

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training = training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training = training)
        return self.layernorm2(out1 + ffn_output)

    def get_config(self):

        config = super().get_config()
        config.update({
            'embed_dim': self.embed_dim,
            'feat_dim': self.feat_dim,
            'num_heads': self.num_heads,
            'ff_dim': self.ff_dim,
            'rate': self.rate,
        })
        return config

# %%
class Time2Vec(keras.layers.Layer):
    def __init__(self, kernel_size = 1):
        super(Time2Vec, self).__init__(trainable = True, name = 'Time2VecLayer')
        self.k = kernel_size

    def build(self, input_shape):
        # trend
        self.wb = self.add_weight(name = 'wb', shape = (input_shape[1],), initializer = 'uniform', trainable = True)
        self.bb = self.add_weight(name = 'bb', shape = (input_shape[1],), initializer = 'uniform', trainable = True)
        # periodic
        self.wa = self.add_weight(name = 'wa', shape = (1, input_shape[1], self.k), initializer = 'uniform', trainable = True)
        self.ba = self.add_weight(name = 'ba', shape = (1, input_shape[1], self.k), initializer = 'uniform', trainable = True)
        super(Time2Vec, self).build(input_shape)

    def call(self, inputs, **kwargs):
        bias = self.wb * inputs + self.bb
        dp = K.dot(inputs, self.wa) + self.ba
        wgts = K.sin(dp) # or K.cos(.)
        ret = K.concatenate([K.expand_dims(bias, -1), wgts], -1)
        ret = K.reshape(ret, (-1, inputs.shape[1] * (self.k + 1)))
        return ret

    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1] * (self.k + 1))

    def get_config(self):

        config = super().get_config()
        config.update({
            'kernel_size': self.k,
        })
        return config

# %%
EPOCHS = 50
N_HEADS = 8
N_FOLDS = 10
FF_DIM = 256
N_BLOCKS = 6
EMBED_DIM = 64
BATCH_SIZE = 16
WINDOW_SIZE = 65
DROPUT_RATE = 0.0
TIME_2_VEC_DIM = 3
TRAIN_MODEL = True
SKIP_CONNECTION_STRENGTH = 0.9

# %%
def get_model(input_shape, time2vec_dim = 3):
    inp = Input(input_shape)
    x = inp

    time_embedding = keras.layers.TimeDistributed(Time2Vec(time2vec_dim - 1))(x)
    x = Concatenate(axis = -1)([x, time_embedding])
    x = layers.LayerNormalization(epsilon = 1e-6)(x)

    for k in range(N_BLOCKS):
        x_old = x
        transformer_block = TransformerBlock(EMBED_DIM, input_shape[-1] + ( input_shape[-1] * time2vec_dim), N_HEADS, FF_DIM, DROPUT_RATE)
        x = transformer_block(x)
        x = ((1.0 - SKIP_CONNECTION_STRENGTH) * x) + (SKIP_CONNECTION_STRENGTH * x_old)

    x = layers.Flatten()(x)

    x = layers.Dense(128, activation = "selu")(x)
    x = layers.Dropout(DROPUT_RATE)(x)
    x = Dense(1, activation = 'linear')(x)

    out = x
    model = Model(inp, out)
    return model

# %%
def get_model2():

    config_defaults = {
    'batch_size': 128,
    'lr': 1e-3,
    'timestep': 3,
    'n_heads': 8,
    'ff_dim':256,
    'n_blocks':6,
    'embed_dim':64,
    'dropout':0,
    'time_2_vec':3,
    }

    wandb.init(config=config_defaults)
    config = wandb.config
    train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y = make_data3(hourly, config.timestep, resid_check=True, resid=False, univariate=False)


    batch_size=config.batch_size
    lr=config.lr
    N_HEADS = config.n_heads
    FF_DIM = config.ff_dim
    N_BLOCKS = config.n_blocks
    EMBED_DIM = config.embed_dim
    DROPUT_RATE = config.dropout
    time2vec_dim = config.time_2_vec

    input_shape = train_X.shape[1:]
    inp = Input(input_shape)
    x = inp

    time_embedding = keras.layers.TimeDistributed(Time2Vec(time2vec_dim - 1))(x)
    x = Concatenate(axis = -1)([x, time_embedding])
    x = layers.LayerNormalization(epsilon = 1e-6)(x)

    for k in range(N_BLOCKS):
        x_old = x
        transformer_block = TransformerBlock(EMBED_DIM, input_shape[-1] + ( input_shape[-1] * time2vec_dim), N_HEADS, FF_DIM, DROPUT_RATE)
        x = transformer_block(x)
        x = ((1.0 - SKIP_CONNECTION_STRENGTH) * x) + (SKIP_CONNECTION_STRENGTH * x_old)

    x = layers.Flatten()(x)

    x = layers.Dense(128, activation = "selu")(x)
    x = layers.Dropout(DROPUT_RATE)(x)
    x = Dense(1, activation = 'linear')(x)

    out = x
    model = Model(inp, out)

    model.compile(
        loss="mse",
        optimizer=Adam(learning_rate=lr)
                  )

    model.fit(train_X, train_y, batch_size=config.batch_size,
              epochs=200, verbose=0, shuffle=False,
              validation_data=(valid_X, valid_y),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=10, restore_best_weights=True)]
              )
    
    yhat = model.predict(test_X)
    yhat_inv = scaler_y.inverse_transform(yhat)
    resid_sum = (yhat_inv+sarima_pred.values[config.timestep:])
    resid_sum2 = (yhat_inv+sarima_pred2.values[config.timestep:])

    wandb.log({"Test_MSE": mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    wandb.log({"Test_RMSE": sqrt(mean_squared_error(resid_sum2, scaler_y.inverse_transform(test_y)))})

    wandb.log({"Test_MAE": mean_absolute_error(resid_sum2, scaler_y.inverse_transform(test_y))})

    wandb.log({"Test_MAPE": mean_absolute_percentage_error(resid_sum2, scaler_y.inverse_transform(test_y))})
    
    return model

# %%
wandb.agent(sweep_id, get_model2, count=50)
# Out:
# wandb: Agent Starting Run: ptap0u4w with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 32
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 2
# wandb: 	resid: True
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 3
# wandb: Currently logged in as: ancy (use `wandb login --relogin` to force relogin)
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_092139-ptap0u4w</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/ptap0u4w" target="_blank">valiant-sweep-1</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▅▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▂▂▃▂▁▁▂▂▁▁▁▁▁▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.08242</td></tr><tr><td>Test_Loss 2</td><td>0.66192</td></tr><tr><td>best_epoch</td><td>42</td></tr><tr><td>best_val_loss</td><td>0.02099</td></tr><tr><td>epoch</td><td>52</td></tr><tr><td>loss</td><td>0.06508</td></tr><tr><td>val_loss</td><td>0.02191</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">valiant-sweep-1</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/ptap0u4w" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/ptap0u4w</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_092139-ptap0u4w/logs</code>
# wandb: Agent Starting Run: xv5jl9jx with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 2
# wandb: 	resid: True
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 12
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_092229-xv5jl9jx</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/xv5jl9jx" target="_blank">jumping-sweep-2</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.352 MB of 1.352 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▅▄▃▃▃▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▂▃▃▂▁</td></tr><tr><td>val_loss</td><td>▂█▄▂▂▃▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▄▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.59863</td></tr><tr><td>Test_Loss 2</td><td>1.32851</td></tr><tr><td>best_epoch</td><td>23</td></tr><tr><td>best_val_loss</td><td>0.02148</td></tr><tr><td>epoch</td><td>33</td></tr><tr><td>loss</td><td>0.20871</td></tr><tr><td>val_loss</td><td>0.0388</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">jumping-sweep-2</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/xv5jl9jx" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/xv5jl9jx</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_092229-xv5jl9jx/logs</code>
# wandb: Agent Starting Run: crvn6s2b with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.1
# wandb: 	embed_dim: 32
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 2
# wandb: 	resid: True
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 8
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_092321-crvn6s2b</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/crvn6s2b" target="_blank">distinctive-sweep-3</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.200 MB of 1.200 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▄▄▅▅▅▆▆▇▇██</td></tr><tr><td>loss</td><td>█▃▃▂▂▂▂▂▂▁▂▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▂▆█▂▁▁▁▁▂▁▂▂▂▃▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.31916</td></tr><tr><td>Test_Loss 2</td><td>0.96843</td></tr><tr><td>best_epoch</td><td>6</td></tr><tr><td>best_val_loss</td><td>0.03426</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>loss</td><td>0.08178</td></tr><tr><td>val_loss</td><td>0.05059</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">distinctive-sweep-3</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/crvn6s2b" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/crvn6s2b</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_092321-crvn6s2b/logs</code>
# wandb: Agent Starting Run: lpjwtbbh with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	resid: False
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 7
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_092414-lpjwtbbh</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/lpjwtbbh" target="_blank">leafy-sweep-4</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.339 MB of 3.339 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▃▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.09119</td></tr><tr><td>Test_Loss 2</td><td>0.62332</td></tr><tr><td>best_epoch</td><td>55</td></tr><tr><td>best_val_loss</td><td>0.02048</td></tr><tr><td>epoch</td><td>65</td></tr><tr><td>loss</td><td>0.03113</td></tr><tr><td>val_loss</td><td>0.02064</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">leafy-sweep-4</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/lpjwtbbh" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/lpjwtbbh</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_092414-lpjwtbbh/logs</code>
# wandb: Agent Starting Run: 04r9j42v with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 4
# wandb: 	resid: True
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 6
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_092606-04r9j42v</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/04r9j42v" target="_blank">lyric-sweep-5</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.019 MB of 3.019 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▁▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.10808</td></tr><tr><td>Test_Loss 2</td><td>0.67793</td></tr><tr><td>best_epoch</td><td>29</td></tr><tr><td>best_val_loss</td><td>0.01918</td></tr><tr><td>epoch</td><td>39</td></tr><tr><td>loss</td><td>0.06161</td></tr><tr><td>val_loss</td><td>0.0215</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">lyric-sweep-5</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/04r9j42v" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/04r9j42v</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_092606-04r9j42v/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: g69izie2 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 4
# wandb: 	resid: True
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 7
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_092730-g69izie2</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/g69izie2" target="_blank">faithful-sweep-6</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.952 MB of 1.952 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▅▄▃▃▃▂▂▂▂▂▂▁▂▂▁▁▁▁▂▂▂▃▃▂▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▃▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.42016</td></tr><tr><td>Test_Loss 2</td><td>1.18183</td></tr><tr><td>best_epoch</td><td>21</td></tr><tr><td>best_val_loss</td><td>0.02247</td></tr><tr><td>epoch</td><td>31</td></tr><tr><td>loss</td><td>0.05886</td></tr><tr><td>val_loss</td><td>0.02683</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">faithful-sweep-6</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/g69izie2" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/g69izie2</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_092730-g69izie2/logs</code>
# wandb: Agent Starting Run: ac3ygdw3 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 2
# wandb: 	resid: True
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 3
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_092821-ac3ygdw3</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/ac3ygdw3" target="_blank">clear-sweep-7</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.768 MB of 1.768 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▃▃▃▂▂▂▂▂▁▁▂▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▆█▅▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.1881</td></tr><tr><td>Test_Loss 2</td><td>0.82217</td></tr><tr><td>best_epoch</td><td>7</td></tr><tr><td>best_val_loss</td><td>0.03442</td></tr><tr><td>epoch</td><td>17</td></tr><tr><td>loss</td><td>0.21754</td></tr><tr><td>val_loss</td><td>0.04685</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">clear-sweep-7</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/ac3ygdw3" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/ac3ygdw3</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_092821-ac3ygdw3/logs</code>
# wandb: Agent Starting Run: j8fnb3t6 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	resid: False
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 4
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_092902-j8fnb3t6</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/j8fnb3t6" target="_blank">flowing-sweep-8</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.386 MB of 3.386 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▃█▄▃▂▁▁▁▁▁▁▂▂▁▁▁▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.16769</td></tr><tr><td>Test_Loss 2</td><td>0.70863</td></tr><tr><td>best_epoch</td><td>24</td></tr><tr><td>best_val_loss</td><td>0.02345</td></tr><tr><td>epoch</td><td>34</td></tr><tr><td>loss</td><td>0.11824</td></tr><tr><td>val_loss</td><td>0.02536</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">flowing-sweep-8</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/j8fnb3t6" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/j8fnb3t6</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_092902-j8fnb3t6/logs</code>
# wandb: Agent Starting Run: wjun7j64 with config:
# wandb: 	batch_size: 128
# wandb: 	dropout: 0
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 4
# wandb: 	resid: False
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 9
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_093013-wjun7j64</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/wjun7j64" target="_blank">treasured-sweep-9</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.667 MB of 3.667 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.20395</td></tr><tr><td>Test_Loss 2</td><td>0.74083</td></tr><tr><td>best_epoch</td><td>109</td></tr><tr><td>best_val_loss</td><td>0.02403</td></tr><tr><td>epoch</td><td>119</td></tr><tr><td>loss</td><td>0.01047</td></tr><tr><td>val_loss</td><td>0.02415</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">treasured-sweep-9</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/wjun7j64" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/wjun7j64</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_093013-wjun7j64/logs</code>
# wandb: Agent Starting Run: bjbfy4bg with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 2
# wandb: 	resid: True
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 6
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_093411-bjbfy4bg</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/bjbfy4bg" target="_blank">earthy-sweep-10</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.196 MB of 1.196 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▅▄▄▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▁▂▂▁▃▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.13238</td></tr><tr><td>Test_Loss 2</td><td>0.71305</td></tr><tr><td>best_epoch</td><td>57</td></tr><tr><td>best_val_loss</td><td>0.01956</td></tr><tr><td>epoch</td><td>67</td></tr><tr><td>loss</td><td>0.04915</td></tr><tr><td>val_loss</td><td>0.01982</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">earthy-sweep-10</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/bjbfy4bg" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/bjbfy4bg</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_093411-bjbfy4bg/logs</code>
# wandb: Agent Starting Run: hpmzgnbe with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 4
# wandb: 	resid: True
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 5
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_093458-hpmzgnbe</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/hpmzgnbe" target="_blank">silvery-sweep-11</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.401 MB of 2.401 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▆▆▅▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄█▂▅▁▃▁▁▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.09083</td></tr><tr><td>Test_Loss 2</td><td>0.6896</td></tr><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.01932</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.05128</td></tr><tr><td>val_loss</td><td>0.02625</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">silvery-sweep-11</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/hpmzgnbe" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/hpmzgnbe</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_093458-hpmzgnbe/logs</code>
# wandb: Agent Starting Run: mkaifhcb with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 2
# wandb: 	resid: True
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 7
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_093554-mkaifhcb</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/mkaifhcb" target="_blank">driven-sweep-12</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.711 MB of 1.711 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▇▅▅▄▄▃▃▃▂▂▃▂▂▂▂▂▂▂▁▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▅▂█▄▁▁▃▂▂▃▅▁▁▂▁▁▁▂▂▃▂▁▁▁▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.09721</td></tr><tr><td>Test_Loss 2</td><td>0.69624</td></tr><tr><td>best_epoch</td><td>29</td></tr><tr><td>best_val_loss</td><td>0.02136</td></tr><tr><td>epoch</td><td>39</td></tr><tr><td>loss</td><td>0.07178</td></tr><tr><td>val_loss</td><td>0.0253</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">driven-sweep-12</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/mkaifhcb" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/mkaifhcb</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_093554-mkaifhcb/logs</code>
# wandb: Agent Starting Run: 6nqt2fvi with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 4
# wandb: 	resid: True
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 6
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_093645-6nqt2fvi</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/6nqt2fvi" target="_blank">toasty-sweep-13</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.590 MB of 4.590 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>loss</td><td>█▅▄▃▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▇▇█▆▂▂▂▂▁▃▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.07748</td></tr><tr><td>Test_Loss 2</td><td>0.66982</td></tr><tr><td>best_epoch</td><td>30</td></tr><tr><td>best_val_loss</td><td>0.01933</td></tr><tr><td>epoch</td><td>40</td></tr><tr><td>loss</td><td>0.04776</td></tr><tr><td>val_loss</td><td>0.01981</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">toasty-sweep-13</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/6nqt2fvi" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/6nqt2fvi</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_093645-6nqt2fvi/logs</code>
# wandb: Agent Starting Run: n17uqxi0 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	resid: False
# wandb: 	time_2_vec: 2
# wandb: 	timestep: 7
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_093804-n17uqxi0</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/n17uqxi0" target="_blank">fearless-sweep-14</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='3.632 MB of 3.632 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▄▄▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▂▁▃█▁▃██▅▂▁▁▁▂▁▁▁▁▄▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.10859</td></tr><tr><td>Test_Loss 2</td><td>0.67471</td></tr><tr><td>best_epoch</td><td>10</td></tr><tr><td>best_val_loss</td><td>0.02028</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>0.08242</td></tr><tr><td>val_loss</td><td>0.02507</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fearless-sweep-14</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/n17uqxi0" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/n17uqxi0</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_093804-n17uqxi0/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: vz86yi8m with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 4
# wandb: 	resid: True
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 5
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_093912-vz86yi8m</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/vz86yi8m" target="_blank">toasty-sweep-15</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.893 MB of 1.893 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▇▅▄▃▃▃▃▃▃▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇█▃▂▃▂▂▁▂▁▁▁▁▁▁▁▂▁▁▁▁▂▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.10753</td></tr><tr><td>Test_Loss 2</td><td>0.7173</td></tr><tr><td>best_epoch</td><td>39</td></tr><tr><td>best_val_loss</td><td>0.01964</td></tr><tr><td>epoch</td><td>49</td></tr><tr><td>loss</td><td>0.04603</td></tr><tr><td>val_loss</td><td>0.02797</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">toasty-sweep-15</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/vz86yi8m" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/vz86yi8m</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_093912-vz86yi8m/logs</code>
# wandb: Agent Starting Run: m2t0v49h with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	resid: True
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 10
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_093958-m2t0v49h</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/m2t0v49h" target="_blank">silvery-sweep-16</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='4.683 MB of 4.683 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▄▄▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▄██▃▁▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.16847</td></tr><tr><td>Test_Loss 2</td><td>0.79601</td></tr><tr><td>best_epoch</td><td>19</td></tr><tr><td>best_val_loss</td><td>0.02033</td></tr><tr><td>epoch</td><td>29</td></tr><tr><td>loss</td><td>0.0723</td></tr><tr><td>val_loss</td><td>0.02346</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">silvery-sweep-16</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/m2t0v49h" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/m2t0v49h</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_093958-m2t0v49h/logs</code>
# wandb: Agent Starting Run: nx0jz8s1 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 4
# wandb: 	resid: True
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 3
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_094157-nx0jz8s1</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/nx0jz8s1" target="_blank">sage-sweep-17</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='5.478 MB of 5.478 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>loss</td><td>█▄▄▄▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▅▄█▄▃▂▂▁▂▂▃▂▁▂▂▃▄▂▁▃▂▄▂▂▃▄▃▁▁▁▂▃▂▂▂▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.05994</td></tr><tr><td>Test_Loss 2</td><td>0.66347</td></tr><tr><td>best_epoch</td><td>28</td></tr><tr><td>best_val_loss</td><td>0.01885</td></tr><tr><td>epoch</td><td>38</td></tr><tr><td>loss</td><td>0.0405</td></tr><tr><td>val_loss</td><td>0.02202</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sage-sweep-17</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/nx0jz8s1" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/nx0jz8s1</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_094157-nx0jz8s1/logs</code>
# wandb: Agent Starting Run: fevcsdn0 with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	resid: False
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 5
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_094314-fevcsdn0</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/fevcsdn0" target="_blank">fanciful-sweep-18</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.555 MB of 0.555 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▄▃▃▃▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>██▃▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.2241</td></tr><tr><td>Test_Loss 2</td><td>0.75462</td></tr><tr><td>best_epoch</td><td>17</td></tr><tr><td>best_val_loss</td><td>0.02228</td></tr><tr><td>epoch</td><td>27</td></tr><tr><td>loss</td><td>0.04993</td></tr><tr><td>val_loss</td><td>0.06015</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fanciful-sweep-18</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/fevcsdn0" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/fevcsdn0</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_094314-fevcsdn0/logs</code>
# wandb: Agent Starting Run: nl6ommzl with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 64
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 8
# wandb: 	resid: True
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 5
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_094436-nl6ommzl</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/nl6ommzl" target="_blank">electric-sweep-19</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='2.626 MB of 2.626 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▆▇▇▇▇███</td></tr><tr><td>loss</td><td>█▆▅▄▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅▂▂▁▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.15692</td></tr><tr><td>Test_Loss 2</td><td>0.72999</td></tr><tr><td>best_epoch</td><td>20</td></tr><tr><td>best_val_loss</td><td>0.01897</td></tr><tr><td>epoch</td><td>30</td></tr><tr><td>loss</td><td>0.08288</td></tr><tr><td>val_loss</td><td>0.03682</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">electric-sweep-19</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/nl6ommzl" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/nl6ommzl</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_094436-nl6ommzl/logs</code>
# wandb: Agent Starting Run: 6aj06z9c with config:
# wandb: 	batch_size: 32
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 256
# wandb: 	n_blocks: 8
# wandb: 	n_heads: 8
# wandb: 	resid: True
# wandb: 	time_2_vec: 3
# wandb: 	timestep: 7
# Tracking run with wandb version 0.12.15
# Run data is saved locally in <code>/content/wandb/run-20220427_094522-6aj06z9c</code>
# Syncing run <strong><a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/6aj06z9c" target="_blank">fresh-sweep-20</a></strong> to <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/sweeps/f9vlkjhp</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='7.754 MB of 7.754 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>▁</td></tr><tr><td>Test_Loss 2</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>loss</td><td>█▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▂▃▃▂▁▁▂▂▁▁▁▁▂▁▁▁▂▂▁▁▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Test_Loss 1</td><td>1.08656</td></tr><tr><td>Test_Loss 2</td><td>0.66469</td></tr><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.01978</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>loss</td><td>0.0655</td></tr><tr><td>val_loss</td><td>0.04267</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fresh-sweep-20</strong>: <a href="https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/6aj06z9c" target="_blank">https://wandb.ai/ancy/recifehora_RESIDUAL_TRANS/runs/6aj06z9c</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20220427_094522-6aj06z9c/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 7j18102g with config:
# wandb: 	batch_size: 64
# wandb: 	dropout: 0.3
# wandb: 	embed_dim: 128
# wandb: 	ff_dim: 128
# wandb: 	n_blocks: 4
# wandb: 	n_heads: 8
# wandb: 	resid: True
# wandb: 	time_2_vec: 4
# wandb: 	timestep: 8

# %% [markdown]
# # Transformer 2

# %%
from tensorflow.keras import layers

# %%
sweep_config = {
    'name': 'Transformer',
    'method': 'bayes', #grid, random
    'metric': {
      'name': 'best_val_loss',
      'goal': 'minimize'   
    },
    'parameters': {
        'batch_size': {
            'values': [256, 128, 64, 32]
        },
        'dropout': {
            'values': [0.1, 0.3, 0.5]
        },
        'units': {
            'values': [64, 128, 256]
        },
        'timestep': {
            'distribution': "int_uniform",
            'min': 1,
            'max': 12
        },
        'head_size': {
            'values': [256, 128, 512]
        },
        'num_heads': {
            'values': [4, 8, 2]
        },
        'ff_dim': {
            'values': [4]
        },
        'num_blocks': {
            'values': [2, 4, 8]
        },
        'lr': {
            'values': [1e-1, 1e-2, 1e-3]
        }
    }
}

# %%
sweep_id = wandb.sweep(sweep_config, entity="ancy", project="Recifehora_oldtrans")
# Out:
# Create sweep with ID: muajowvf
# Sweep URL: https://wandb.ai/ancy/Recifehora_oldtrans/sweeps/muajowvf

# %%
def transformer_encoder(inputs, head_size=256, num_heads=4, ff_dim=4, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
def build_model():

    config_defaults = {
    'batch_size': 128,
    'lr': 1e-3,
    'units': 64,
    'timestep': 3,
    'dropout': 0.3,
    'head_size': 256,
    'num_heads': 4,
    'ff_dim': 4,
    'num_blocks': 4
    }
    wandb.init(config=config_defaults)
    config = wandb.config
    train_X, train_y, valid_X, valid_y, test_X, test_y, scaler, scaler_y = make_data2(hourly, config.timestep, resid_check=True)


    num_transformer_blocks=config.num_blocks
    inputs = keras.Input(shape=train_X.shape[1:])
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size=config.head_size, num_heads=config.num_heads, ff_dim=config.ff_dim, dropout=config.dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    x = layers.Dense(config.units, activation="relu")(x)
    x = layers.Dropout(config.dropout)(x)
    outputs = layers.Dense(1)(x)

    lr = config.lr

    model = keras.Model(inputs, outputs)
    model.compile(
        loss="mse",
        optimizer=Adam(learning_rate=lr)
    )

    model.fit(train_X, train_y, batch_size=config.batch_size,
              epochs=200, verbose=0, shuffle=False,
              validation_data=(valid_X, valid_y),
              callbacks=[WandbCallback(),
                          EarlyStopping(patience=10, restore_best_weights=True), ReduceLROnPlateau(monitor='val_loss',patience=5, min_lr=1e-6)])
    
      
    yhat = model.predict(test_X)
    yhat_inv = scaler_y.inverse_transform(yhat)
    resid_sum = (yhat_inv+sarima_pred.values[config.timestep:])

    print(sqrt(mean_squared_error(resid_sum, scaler_y.inverse_transform(test_y))))
    print(mean_absolute_error(resid_sum, scaler_y.inverse_transform(test_y)))
    print(mean_absolute_percentage_error(resid_sum, scaler_y.inverse_transform(test_y)))

    
    return keras.Model(inputs, outputs)

# %%
wandb.agent(sweep_id, build_model, count=50)
